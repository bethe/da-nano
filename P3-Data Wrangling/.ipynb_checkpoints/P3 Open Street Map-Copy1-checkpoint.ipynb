# %% [markdown]
# # P3 Wrangle Open Street Map Data

# %% [markdown]
# ## 1 Initial Parse of the file

# %%
import xml.etree.cElementTree as ET
import pprint

# %%
filename_short = "/media/removable/Elements/Udacity Data Monging Course/dublin_short.osm"
filename_addr = "/media/removable/Elements/Udacity Data Monging Course/elephants_ear.osm"
filename = "/media/removable/Elements/Udacity Data Monging Course/dublin_ireland.osm"

# %%
 def count_tags_k(filename):
    # initialize dict objects and counter
    tag_count = {}
    tag_keys = {}
    counter = 0

    for _, element in ET.iterparse(filename, events=("start",)):
        # add to tag count
        if element.tag in tag_count:
            tag_count[element.tag] += 1
        else:
            tag_count[element.tag] = 1

        # if tag and has key, add the tag key to tag_keys dict
        if element.tag == 'tag' and 'k' in element.attrib:
            #add_tag(element.get('k'), tag_keys)
            if element.get('k') in tag_keys:
                tag_keys[element.get('k')] += 1
            else:
                tag_keys[element.get('k')] = 1

    # produces sorted-by-decreasing lists of tag key-count pairs
    tag_count = sorted(tag_count.items(), key=lambda t: t[1], reverse = True)
    tag_keys = sorted(tag_keys.items(), key=lambda t: t[1], reverse = True)

    # return values
    return tag_count, tag_keys

# %%
count_tags_k(filename)
# Out:
# ([('nd', 1450408),
#   ('node', 1068565),
#   ('tag', 764612),
#   ('way', 187706),
#   ('member', 59217),
#   ('relation', 3391),
#   ('bounds', 1),
#   ('osm', 1)],
#  [('building', 99787),
#   ('addr:street', 82432),
#   ('addr:housenumber', 71061),
#   ('highway', 66932),
#   ('name', 45890),
#   ('house', 42879),
#   ('building:levels', 37375),
#   ('building:roof:shape', 29419),
#   ('maxspeed', 24675),
#   ('addr:city', 13774),
#   ('created_by', 13301),
#   ('levels', 12457),
#   ('name:ga', 12396),
#   ('landuse', 10206),
#   ('amenity', 9990),
#   ('oneway', 7947),
#   ('ref', 7858),
#   ('natural', 7732),
#   ('barrier', 6959),
#   ('building:use', 6877),
#   ('source', 6783),
#   ('building:cladding', 5950),
#   ('operator', 5782),
#   ('name:en', 5725),
#   ('service', 5581),
#   ('building:roof', 4579),
#   ('access', 4128),
#   ('surface', 4095),
#   ('addr:country', 3732),
#   ('boundary', 3469),
#   ('type', 3417),
#   ('shop', 3388),
#   ('foot', 3291),
#   ('leisure', 3168),
#   ('traffic_calming', 3089),
#   ('building:roof_shape', 2635),
#   ('admin_level', 2509),
#   ('addr:housename', 2500),
#   ('power', 2480),
#   ('website', 2319),
#   ('railway', 2303),
#   ('layer', 2281),
#   ('building:type', 2274),
#   ('bicycle', 2269),
#   ('waterway', 2197),
#   ('year_built', 2189),
#   ('lanes', 1896),
#   ('note', 1779),
#   ('phone', 1654),
#   ('bridge', 1653),
#   ('shelter', 1587),
#   ('place', 1551),
#   ('electrified', 1417),
#   ('gauge', 1415),
#   ('passenger', 1373),
#   ('locality', 1356),
#   ('bench', 1250),
#   ('sport', 1210),
#   ('cycleway', 1051),
#   ('tactile_paving', 1048),
#   ('horse', 968),
#   ('voltage', 949),
#   ('frequency', 929),
#   ('cuisine', 921),
#   ('boat', 917),
#   ('usage', 873),
#   ('parking', 854),
#   ('addr:interpolation', 837),
#   ('tracks', 797),
#   ('office', 775),
#   ('alt_name', 761),
#   ('junction', 755),
#   ('tunnel', 728),
#   ('wheelchair', 673),
#   ('tourism', 669),
#   ('crossing', 647),
#   ('area', 641),
#   ('addr:postcode', 637),
#   ('opening_hours', 630),
#   ('public_transport', 617),
#   ('man_made', 609),
#   ('FIXME', 511),
#   ('religion', 489),
#   ('width', 467),
#   ('restriction', 442),
#   ('building-roof-shape', 437),
#   ('roof:shape', 424),
#   ('roof:colour', 419),
#   ('roof:angle', 412),
#   ('entrance', 407),
#   ('roof:orientation', 405),
#   ('lit', 385),
#   ('historic', 380),
#   ('covered', 379),
#   ('capacity', 370),
#   ('tracktype', 369),
#   ('denomination', 369),
#   ('fee', 364),
#   ('route_ref', 361),
#   ('motor_vehicle', 321),
#   ('alt_name_1', 315),
#   ('noexit', 293),
#   ('direction', 290),
#   ('network', 269),
#   ('aeroway', 268),
#   ('email', 268),
#   ('is_in', 242),
#   ('motorcar', 240),
#   ('route', 233),
#   ('golf', 225),
#   ('embankment', 219),
#   ('int_ref', 207),
#   ('motorcycle', 206),
#   ('cables', 203),
#   ('wikipedia', 196),
#   ('is_in:country', 185),
#   ('is_in:county', 182),
#   ('level', 175),
#   ('smoking', 173),
#   ('place_county', 169),
#   ('maxweight', 169),
#   ('alt_name_2', 161),
#   ('material', 156),
#   ('gns:UFI', 149),
#   ('gns:JOG', 149),
#   ('gns:CC1', 149),
#   ('gns:MGRS', 149),
#   ('park_ride', 149),
#   ('gns:RC', 149),
#   ('gns:UNI', 149),
#   ('gns:DSG', 149),
#   ('gns:LONG', 149),
#   ('gns:DMS_LONG', 149),
#   ('gns:DMS_LAT', 149),
#   ('gns:FC', 149),
#   ('gns:LAT', 149),
#   ('gns:ADM1', 149),
#   ('bus', 138),
#   ('fax', 135),
#   ('wires', 132),
#   ('gns:N:xx:FULL_NAME_ND', 130),
#   ('gns:N:xx:FULL_NAME', 130),
#   ('gns:N:xx:SORT_NAME', 130),
#   ('backrest', 130),
#   ('gns:N:xx:MODIFY_DATE', 130),
#   ('gns:N:xx:NT', 130),
#   ('old_name', 130),
#   ('segregated', 128),
#   ('cutting', 126),
#   ('atm', 124),
#   ('bridge:ref', 124),
#   ('bicycle_parking', 122),
#   ('history', 120),
#   ('trail_visibility', 118),
#   ('height', 118),
#   ('toll', 116),
#   ('fence_type', 113),
#   ('sac_scale', 110),
#   ('political_division', 107),
#   ('indoor', 106),
#   ('colour', 103),
#   ('construction', 103),
#   ('leaf_type', 101),
#   ('fixme', 101),
#   ('drive_through', 101),
#   ('emergency', 100),
#   ('description', 99),
#   ('footway', 92),
#   ('takeaway', 91),
#   ('artwork_type', 85),
#   ('passenger_information_display', 83),
#   ('internet_access', 83),
#   ('supervised', 82),
#   ('url', 81),
#   ('smoothness', 79),
#   ('surveillance', 77),
#   ('brand', 76),
#   ('maxheight', 76),
#   ('contact:facebook', 75),
#   ('date', 73),
#   ('recycling:glass', 72),
#   ('leaf_cycle', 72),
#   ('sidewalk', 71),
#   ('psv', 71),
#   ('step_count', 71),
#   ('seats', 68),
#   ('line', 66),
#   ('local_ref', 65),
#   ('source:ref', 61),
#   ('lanes:forward', 60),
#   ('artist_name', 57),
#   ('ele', 57),
#   ('craft', 57),
#   ('vending', 56),
#   ('turn:lanes:backward', 55),
#   ('logainm:ref', 54),
#   ('turn:lanes:forward', 53),
#   ('to', 53),
#   ('turn:lanes', 53),
#   ('dispensing', 53),
#   ('tower:type', 52),
#   ('from', 52),
#   ('shelter_type', 52),
#   ('designation', 51),
#   ('start_date', 51),
#   ('information', 50),
#   ('building:colour', 50),
#   ('collection_times', 50),
#   ('loc_name', 49),
#   ('lanes:backward', 49),
#   ('water', 48),
#   ('payment:coins', 47),
#   ('os:ref', 47),
#   ('substation', 47),
#   ('recycling:cans', 47),
#   ('official_name:ga', 45),
#   ('lock_name', 45),
#   ('bridge:name', 44),
#   ('capacity:disabled', 44),
#   ('hgv', 44),
#   ('incline', 44),
#   ('disused', 43),
#   ('country', 42),
#   ('ele:local', 42),
#   ('loc_ref', 41),
#   ('food', 40),
#   ('official_name:en', 40),
#   ('proposed', 40),
#   ('exit_to', 38),
#   ('contact:twitter', 38),
#   ('crossing_ref', 38),
#   ('height_source', 37),
#   ('live_departure_info', 37),
#   ('day_off', 35),
#   ('lock', 35),
#   ('hour_off', 35),
#   ('day_on', 35),
#   ('hour_on', 35),
#   ('seamark:type', 33),
#   ('lock:height', 33),
#   ('recycling_type', 32),
#   ('recycling:clothes', 31),
#   ('alt_name:ga', 31),
#   ('addr:terracename', 31),
#   ('building:part', 30),
#   ('addr:street:ga', 30),
#   ('delivery', 30),
#   ('maxstay', 29),
#   ('addr:city:ga', 28),
#   ('currency:EUR', 28),
#   ('complete', 28),
#   ('content', 27),
#   ('residential', 27),
#   ('corine', 27),
#   ('source:name', 26),
#   ('motorboat', 26),
#   ('goods', 26),
#   ('seamark:light:colour', 24),
#   ('seamark:light:character', 24),
#   ('contact:phone', 24),
#   ('private', 23),
#   ('wifi', 23),
#   ('source:name:ga', 22),
#   ('social_facility:for', 22),
#   ('role', 22),
#   ('source:url', 20),
#   ('male', 20),
#   ('gns:N:eng:LC', 19),
#   ('gns:N:eng:MODIFY_DATE', 19),
#   ('gns:N:gle:LC', 19),
#   ('contact:email', 19),
#   ('snowmobile', 19),
#   ('gns:N:gle:SORT_NAME', 19),
#   ('gns:N:gle:MODIFY_DATE', 19),
#   ('except', 19),
#   ('location', 19),
#   ('ski', 19),
#   ('gns:N:eng:NT', 19),
#   ('stars', 19),
#   ('gns:N:gle:FULL_NAME_ND', 19),
#   ('gns:N:gle:NT', 19),
#   ('gns:N:eng:SORT_NAME', 19),
#   ('gns:N:gle:FULL_NAME', 19),
#   ('clothes', 18),
#   ('gns:N:eng:FULL_NAME', 18),
#   ('addr:postal_district', 18),
#   ('internet_access:fee', 18),
#   ('gns:N:eng:FULL_NAME_ND', 18),
#   ('highway_1', 18),
#   ('mtb:scale', 18),
#   ('female', 18),
#   ('school', 17),
#   ('recycling:paper', 17),
#   ('vehicle', 17),
#   ('species', 17),
#   ('payment:mastercard', 17),
#   ('seamark:name', 17),
#   ('ele:tm75', 17),
#   ('payment:visa', 17),
#   ('tidal', 17),
#   ('addr:county', 17),
#   ('architect', 16),
#   ('taxi', 16),
#   ('seamark:light:reference', 16),
#   ('seamark:light:period', 16),
#   ('fuel:diesel', 16),
#   ('voltage-low', 16),
#   ('voltage-high', 15),
#   ('building:min_level', 15),
#   ('outdoor_seating', 15),
#   ('official_name', 15),
#   ('generator:source', 15),
#   ('level_crossing:ref', 14),
#   ('seamark:light:height', 14),
#   ('lanes:left', 14),
#   ('capacity:parent', 14),
#   ('ruins', 14),
#   ('lanes:right', 14),
#   ('cargo', 13),
#   ('old_ref', 13),
#   ('seamark:light:range', 13),
#   ('addr:apartments', 13),
#   ('ramp', 13),
#   ('cycleway:left', 13),
#   ('public_transport:version', 13),
#   ('display', 13),
#   ('fire_hydrant:type', 13),
#   ('lawyer', 12),
#   ('payment:bitcoin', 12),
#   ('fire_hydrant:position', 12),
#   ('generator:method', 12),
#   ('lanes:psv', 12),
#   ('building:material', 12),
#   ('building:roof:type', 12),
#   ('live_departure_information', 12),
#   ('wetland', 12),
#   ('iemv:gpsname6', 11),
#   ('iemv:mtnarea', 11),
#   ('addr:place', 11),
#   ('healthcare', 11),
#   ('iemv:importtime', 11),
#   ('iemv:lat', 11),
#   ('toilets:wheelchair', 11),
#   ('duration', 11),
#   ('iemv:lon', 11),
#   ('iemv:sourcetime', 11),
#   ('cycleway:right', 11),
#   ('iemv:gpsname10', 11),
#   ('destination', 11),
#   ('iemv:mtnindex', 11),
#   ('ele:wgs84', 11),
#   ('ele_local', 11),
#   ('iemv:mtnsubarea', 10),
#   ('name:pl', 10),
#   ('payment:telephone_cards', 10),
#   ('post_box', 10),
#   ('wikidata', 10),
#   ('amperage', 10),
#   ('recycling:glass_bottles', 10),
#   ('grass', 10),
#   ('anglican', 9),
#   ('military', 9),
#   ('sloped_curb', 9),
#   ('theatre:genre', 9),
#   ('HSE_region', 9),
#   ('HSE_hgid', 9),
#   ('ramp:wheelchair', 9),
#   ('gns:V:xx:FULL_NAME_ND', 9),
#   ('gns:V:xx:MODIFY_DATE', 9),
#   ('seamark:light:sequence', 9),
#   ('source:geometry', 9),
#   ('gns:V:xx:NT', 9),
#   ('phone:mobile', 9),
#   ('gns:V:xx:FULL_NAME', 9),
#   ('HSE_hgroup', 9),
#   ('source:maxspeed', 9),
#   ('gns:V:xx:SORT_NAME', 9),
#   ('fuel:octane_95', 9),
#   ('addr:housename:ga', 9),
#   ('route_master', 9),
#   ('contact:website', 9),
#   ('HSE_code', 9),
#   ('source:amenity', 8),
#   ('contact:google_plus', 8),
#   ('hoops', 8),
#   ('animal', 8),
#   ('bridge:movable', 8),
#   ('zoo', 8),
#   ('healthcare:speciality', 8),
#   ('contact:fax', 8),
#   ('wheelchair:description', 8),
#   ('recycling:batteries', 8),
#   ('mph:maxspeed', 8),
#   ('name:de', 8),
#   ('transformer', 8),
#   ('survey:date', 7),
#   ('visibility', 7),
#   ('ferry', 7),
#   ('diet:gluten_free', 7),
#   ('stile', 7),
#   ('service:bicycle:repair', 7),
#   ('driveway', 7),
#   ('disused:amenity', 7),
#   ('social_facility', 7),
#   ('distance', 7),
#   ('seamark:reference', 7),
#   ('comment', 7),
#   ('alt_name:en', 7),
#   ('payment:notes', 7),
#   ('support', 7),
#   ('service:bicycle:retail', 6),
#   ('handrail', 6),
#   ('club', 6),
#   ('name:fr', 6),
#   ('abutters', 6),
#   ('scenic', 6),
#   ('mtb:scale:uphill', 6),
#   ('brewery', 6),
#   ('name:sk', 6),
#   ('source:vending', 6),
#   ('bridge:name:ga', 6),
#   ('diplomatic', 6),
#   ('traffic_signals:sound', 6),
#   ('culvert', 6),
#   ('destination:lanes:forward', 6),
#   ('bridge:name:en', 6),
#   ('fire_hydrant:diameter', 6),
#   ('gambling', 6),
#   ('capacity:women', 6),
#   ('name:ga:absent', 5),
#   ('name:it', 5),
#   ('has_riverbank', 5),
#   ('car', 5),
#   ('monitoring:bicycle', 5),
#   ('seamark:cable_submarine:category', 5),
#   ('logainm', 5),
#   ('second_hand', 5),
#   ('seamark:light:group', 5),
#   ('payment:credit_cards', 5),
#   ('name:ru', 5),
#   ('recycling:plastic', 5),
#   ('submarine', 5),
#   ('local_class', 5),
#   ('gay', 5),
#   ('toilets:disposal', 5),
#   ('communication', 5),
#   ('addr:flats', 5),
#   ('is_in:country_code', 5),
#   ('icao', 4),
#   ('name:uk', 4),
#   ('roof:height', 4),
#   ('commercial', 4),
#   ('microbrewery', 4),
#   ('seamark:light:category', 4),
#   ('payment:electronic_purses', 4),
#   ('ISO3166-2', 4),
#   ('inscription', 4),
#   ('length', 4),
#   ('seamark:buoy_cardinal:colour_pattern', 4),
#   ('ref:national_rail', 4),
#   ('set_down', 4),
#   ('name:absent', 4),
#   ('name:sr', 4),
#   ('thermometer', 4),
#   ('seamark:buoy_cardinal:colour', 4),
#   ('generator:output:electricity', 4),
#   ('board_type', 4),
#   ('region', 4),
#   ('church', 4),
#   ('recycling:cartons', 4),
#   ('disused:shop', 4),
#   ('steps', 4),
#   ('contact:youtube', 4),
#   ('name:ja', 4),
#   ('name:old', 4),
#   ('seamark:buoy_cardinal:category', 4),
#   ('traffic_sign', 4),
#   ('min_height', 4),
#   ('name:zh', 3),
#   ('disused:operator', 3),
#   ('section', 3),
#   ('cycleway:oneway', 3),
#   ('name:be', 3),
#   ('name:bg', 3),
#   ('caravans', 3),
#   ('surveillance:type', 3),
#   ('osmc:symbol', 3),
#   ('recycling:plastic_packaging', 3),
#   ('name:et', 3),
#   ('organic', 3),
#   ('name:nl', 3),
#   ('stream', 3),
#   ('industrial', 3),
#   ('seamark:light:multiple', 3),
#   ('recycling:newspaper', 3),
#   ('recycling:electrical_appliances', 3),
#   ('city_served', 3),
#   ('gender', 3),
#   ('toilets:position', 3),
#   ('recycling:plastic_bottles', 3),
#   ('name:an', 3),
#   ('name:sv', 3),
#   ('maxwheels', 3),
#   ('name:hu', 3),
#   ('population', 3),
#   ('name:is', 3),
#   ('recycling:cardboard', 3),
#   ('recycling:scrap_metal', 3),
#   ('building:levels:underground', 3),
#   ('name:ka', 3),
#   ('spaces', 3),
#   ('name:cv', 3),
#   ('name:lt', 3),
#   ('name:el', 3),
#   ('name:eo', 3),
#   ('name:es', 3),
#   ('name:ko', 3),
#   ('name:ta', 3),
#   ('seamark:buoy_lateral:category', 3),
#   ('loc_name:ga', 3),
#   ('recycling:small_appliances', 3),
#   ('wall', 3),
#   ('url_ref', 3),
#   ('hobby', 3),
#   ('busway', 3),
#   ('vehicle:backward', 3),
#   ('memorial', 3),
#   ('gaelic_games:football', 3),
#   ('landmark', 3),
#   ('name:cs', 3),
#   ('name:ca', 3),
#   ('plots', 3),
#   ('seamark:buoy_lateral:system', 3),
#   ('name:da', 3),
#   ('lcn', 3),
#   ('seamark:buoy_lateral:colour', 3),
#   ('platforms', 3),
#   ('vending_1', 3),
#   ('name:no', 3),
#   ('traffic_signals:vibration', 3),
#   ('doctors', 3),
#   ('memorial:type', 3),
#   ('unisex', 3),
#   ('source:height', 3),
#   ('disused:name', 3),
#   ('drinking_water', 3),
#   ('aerialway', 3),
#   ('recycling:paper_packaging', 3),
#   ('finely_mown', 3),
#   ('gender_access', 3),
#   ('seamark:fog_signal:group', 2),
#   ('name:ast', 2),
#   ('name:kn', 2),
#   ('name:kk', 2),
#   ('alt_ref', 2),
#   ('name:ur', 2),
#   ('recycling:magazines', 2),
#   ('scout', 2),
#   ('bridge:structure', 2),
#   ('is_in:continent', 2),
#   ('name:hy', 2),
#   ('disused:line', 2),
#   ('name:nrm', 2),
#   ('name:etymology:wikidata', 2),
#   ('access:conditional', 2),
#   ('name:pnb', 2),
#   ('name:bat-smg', 2),
#   ('name:br', 2),
#   ('name:bo', 2),
#   ('massage', 2),
#   ('name:pt', 2),
#   ('via', 2),
#   ('name:ps', 2),
#   ('opening_date', 2),
#   ('recycling:wood', 2),
#   ('name:sq', 2),
#   ('addr:unit', 2),
#   ('name:ro', 2),
#   ('name:scn', 2),
#   ('loc_name:en', 2),
#   ('roof', 2),
#   ('name:mr', 2),
#   ('recycling:green_waste', 2),
#   ('name:my', 2),
#   ('box_type', 2),
#   ('name:ml', 2),
#   ('name:mn', 2),
#   ('name:mk', 2),
#   ('name:fi', 2),
#   ('operator:de', 2),
#   ('iata', 2),
#   ('name:fa', 2),
#   ('pdop', 2),
#   ('recycling:waste', 2),
#   ('name:tt', 2),
#   ('contact:instagram', 2),
#   ('name:tg', 2),
#   ('kindergarten', 2),
#   ('derelict', 2),
#   ('piste:difficulty', 2),
#   ('conveying', 2),
#   ('name:left', 2),
#   ('contact:linkedin', 2),
#   ('name_1', 2),
#   ('name:ar', 2),
#   ('name:am', 2),
#   ('seamark:small_craft_facility:category', 2),
#   ('name:hr', 2),
#   ('ret', 2),
#   ('playground', 2),
#   ('name:sl', 2),
#   ('hairdresser', 2),
#   ('name:sc', 2),
#   ('disused:name:en', 2),
#   ('name:arc', 2),
#   ('area:highway', 2),
#   ('seasonal', 2),
#   ('name:xmf', 2),
#   ('goods:opening_hours', 2),
#   ('paved', 2),
#   ('name:he', 2),
#   ('manhole', 2),
#   ('name:ht', 2),
#   ('castle_type', 2),
#   ('name:lmo', 2),
#   ('name:arz', 2),
#   ('seamark:fog_signal:category', 2),
#   ('source:highway', 2),
#   ('length_unit', 2),
#   ('fuel:electricity', 2),
#   ('toilets', 2),
#   ('name:ang', 2),
#   ('disused:railway', 2),
#   ('name:kw', 2),
#   ('name:ku', 2),
#   ('name:tr', 2),
#   ('name:lv', 2),
#   ('wifi:free', 2),
#   ('name:la', 2),
#   ('name:th', 2),
#   ('int_name', 2),
#   ('name:ckb', 2),
#   ('e-road:class', 2),
#   ('vdop', 2),
#   ('screen', 2),
#   ('manometer', 2),
#   ('name:bs', 2),
#   ('name:bn', 2),
#   ('name:sah', 2),
#   ('name:udm', 2),
#   ('name:os', 2),
#   ('landuse_1', 2),
#   ('short_name', 2),
#   ('name:krc', 2),
#   ('hdop', 2),
#   ('building_1', 2),
#   ('abandoned', 2),
#   ('station_ref', 2),
#   ('runway', 2),
#   ('name:yi', 2),
#   ('ruin_type', 2),
#   ('name:vo', 2),
#   ('name:ext', 2),
#   ('baby_changing', 2),
#   ('name:be-x-old', 2),
#   ('building:source', 2),
#   ('name:cy', 2),
#   ('name:lb', 2),
#   ('books', 2),
#   ('payment:debit_cards', 2),
#   ('recycling:glass_bottle', 2),
#   ('isced:level', 2),
#   ('bollard', 2),
#   ('furniture', 2),
#   ('former_amenity', 2),
#   ('traffic_signals:arrow', 2),
#   ('recycling:furniture', 2),
#   ('seamark:fog_signal:period', 2),
#   ('name:nn', 2),
#   ('destination:lanes', 2),
#   ('name:zh-yue', 2),
#   ('surveillance:zone', 2),
#   ('highway:normal', 2),
#   ('repair', 2),
#   ('golf:course:par', 2),
#   ('disused:name:ga', 2),
#   ('name:qu', 2),
#   ('bus:lanes', 2),
#   ('monument', 2),
#   ('cafe', 2),
#   ('traffic_signals:direction', 2),
#   ('name:gd', 2),
#   ('name:gl', 2),
#   ('train', 2),
#   ('name:gv', 2),
#   ('time', 2),
#   ('health_facility:type', 1),
#   ('seamark:beacon_lateral:system', 1),
#   ('barony', 1),
#   ('name:nds-nl', 1),
#   ('seamark:light:2:group', 1),
#   ('gaelic_games:hurling', 1),
#   ('name:gag', 1),
#   ('vehicle:forward', 1),
#   ('building:height', 1),
#   ('seamark:light:2:character', 1),
#   ('contact:pintrest', 1),
#   ('alt_name:en_1', 1),
#   ('alt_name:en_2', 1),
#   ('name:zu', 1),
#   ('oneway:vehicle', 1),
#   ('name:za', 1),
#   ('name:uz', 1),
#   ('name:als', 1),
#   ('traffic_signals:minimap', 1),
#   ('facebook', 1),
#   ('name:ki', 1),
#   ('acres', 1),
#   ('name:ug', 1),
#   ('addr:terrace', 1),
#   ('condition', 1),
#   ('name:rw', 1),
#   ('website:operator', 1),
#   ('region_type', 1),
#   ('timezone', 1),
#   ('name:ks', 1),
#   ('name:ia', 1),
#   ('name:lez', 1),
#   ('service:computer', 1),
#   ('name:sn', 1),
#   ('razed', 1),
#   ('sign', 1),
#   ('toddler_area', 1),
#   ('service:press', 1),
#   ('seamark:beacon_lateral:category', 1),
#   ('name:sh', 1),
#   ('name:sg', 1),
#   ('capital', 1),
#   ('lutheran', 1),
#   ('opening_hours:helpline', 1),
#   ('seamark:beacon_lateral:colour', 1),
#   ('lgbt', 1),
#   ('beacon', 1),
#   ('opening_hours:foot', 1),
#   ('name:bi', 1),
#   ('landcover', 1),
#   ('recycling:tv_monitor', 1),
#   ('name:ba', 1),
#   ('recycling:engine_oil', 1),
#   ('passengers', 1),
#   ('colour:back', 1),
#   ('name:kbd', 1),
#   ('name:jv', 1),
#   ('is_in:suburb', 1),
#   ('hiking', 1),
#   ('county', 1),
#   ('name:sw', 1),
#   ('compressed_air', 1),
#   ('name:ss', 1),
#   ('hospital', 1),
#   ('diet:vegetarian', 1),
#   ('accommodation', 1),
#   ('name:cdo', 1),
#   ('seamark:topmark:colour', 1),
#   ('colour:text', 1),
#   ('tower:construction', 1),
#   ('recycling:oil', 1),
#   ('pipeline', 1),
#   ('flag', 1),
#   ('name:vec', 1),
#   ('name:pnt', 1),
#   ('uic_ref', 1),
#   ('fuel:GTL_diesel', 1),
#   ('google_plus', 1),
#   ('oneway:foot', 1),
#   ('name:bxr', 1),
#   ('country_code_fips', 1),
#   ('recycling:cooking_oil', 1),
#   ('name:bug', 1),
#   ('species:en', 1),
#   ('name:lad', 1),
#   ('currency', 1),
#   ('name:mg', 1),
#   ('name:vi', 1),
#   ('name:mi', 1),
#   ('navigationalaid', 1),
#   ('disused:route', 1),
#   ('name:ff', 1),
#   ('source:cuisine', 1),
#   ('name:ms', 1),
#   ('colour:arrow', 1),
#   ('operator:nl', 1),
#   ('name:fy', 1),
#   ('ISO3166-1', 1),
#   ('veterinary', 1),
#   ('beauty', 1),
#   ('name:zea', 1),
#   ('movable', 1),
#   ('ship:type', 1),
#   ('addr:town', 1),
#   ('old_name:ga', 1),
#   ('seamark:buoy_safe_water:colour_pattern', 1),
#   ('name:fiu-vro', 1),
#   ('official_name:la', 1),
#   ('fuel:cng', 1),
#   ('order', 1),
#   ('name:roa-rup', 1),
#   ('shoes', 1),
#   ('name:ts', 1),
#   ('trade', 1),
#   ('payment:cash', 1),
#   ('ticket', 1),
#   ('post_office', 1),
#   ('name:te', 1),
#   ('roundtrip', 1),
#   ('police', 1),
#   ('name:kv', 1),
#   ('organisation', 1),
#   ('name:pms', 1),
#   ('grade', 1),
#   ('drive_in', 1),
#   ('ISO3166-1:alpha2', 1),
#   ('image', 1),
#   ('payment:leap', 1),
#   ('source:population', 1),
#   ('seamark:light:1:height', 1),
#   ('name:gan', 1),
#   ('busway:left', 1),
#   ('roof:material', 1),
#   ('name:ay', 1),
#   ('alt_phone', 1),
#   ('rating', 1),
#   ('ISO3166-1:numeric', 1),
#   ('contact:tumblr', 1),
#   ('naptan:Bearing', 1),
#   ('seamark:light:1:group', 1),
#   ('name:ak', 1),
#   ('seamark:light:2:sequence', 1),
#   ('lanes:psv:forward', 1),
#   ('operatorSB', 1),
#   ('seamark:light:1:sector_start', 1),
#   ('social_facility_for', 1),
#   ('other_use', 1),
#   ('name:so', 1),
#   ('name:war', 1),
#   ('name:se', 1),
#   ('name:hif', 1),
#   ('biergarten', 1),
#   ('seamark:light:1:period', 1),
#   ('cycleway_1', 1),
#   ('name:tpi', 1),
#   ('notes', 1),
#   ('name:rn', 1),
#   ('parking:lane:both', 1),
#   ('is_capital', 1),
#   ('name:botanical', 1),
#   ('name:diq', 1),
#   ('time:absent', 1),
#   ('owner', 1),
#   ('name:ie', 1),
#   ('tailor:alteration_service', 1),
#   ('seamark:buoy_safe_water:shape', 1),
#   ('name:id', 1),
#   ('phone:helpline', 1),
#   ('blood:whole', 1),
#   ('maxheight:physical', 1),
#   ('seamark:light:1:range', 1),
#   ('est_width', 1),
#   ('service:bicycle:pump', 1),
#   ('name:ha', 1),
#   ('website:source_data', 1),
#   ('gns:POP', 1),
#   ('photograph', 1),
#   ('name:rmy', 1),
#   ('target', 1),
#   ('operator:sk', 1),
#   ('archery:type', 1),
#   ('rtc_rate', 1),
#   ('contact:skype', 1),
#   ('historical', 1),
#   ('note:name', 1),
#   ('name:vls', 1),
#   ('addr:floor', 1),
#   ('halal', 1),
#   ('name:right', 1),
#   ('population:date', 1),
#   ('recycling:garden_waste', 1),
#   ('escalator', 1),
#   ('recycling:low_energy_bulbs', 1),
#   ('name:hi', 1),
#   ('internal', 1),
#   ('lanes:psv:backward', 1),
#   ('name:xal', 1),
#   ('is_in:ocean', 1),
#   ('name:wa', 1),
#   ('megalith_type', 1),
#   ('old_name:ku', 1),
#   ('name:pcd', 1),
#   ('payment', 1),
#   ('old_name2', 1),
#   ('m', 1),
#   ('name:ceb', 1),
#   ('name:nds', 1),
#   ('name:km', 1),
#   ('seamark:radar_transponder:category', 1),
#   ('gaelic_games:camogie', 1),
#   ('name:ky', 1),
#   ('ground', 1),
#   ('fuel:HGV_diesel', 1),
#   ('name:frp', 1),
#   ('payment:laser', 1),
#   ('theme', 1),
#   ('wood', 1),
#   ('name:tet', 1),
#   ('name:cu', 1),
#   ('seamark:buoy_safe_water:colour', 1),
#   ('int_network', 1),
#   ('name:csb', 1),
#   ('name:si', 1),
#   ('recycling:fluorescent_tubes', 1),
#   ('name:li', 1),
#   ('name:ln', 1),
#   ('name:lo', 1),
#   ('seamark:light:1:colour', 1),
#   ('name:tk', 1),
#   ('name:ee', 1),
#   ('seamark:light:1:sequence', 1),
#   ('name:ti', 1),
#   ('name:lij', 1),
#   ('name:eu', 1),
#   ('rooms', 1),
#   ('name:rm', 1),
#   ('name:tl', 1),
#   ('name:ltg', 1),
#   ('railway:disused', 1),
#   ('cocktails', 1),
#   ('name:co', 1),
#   ('operator:bg', 1),
#   ('name:ce', 1),
#   ('fire_hydrant:count', 1),
#   ('subject', 1),
#   ('maxwidth', 1),
#   ('seamark:light:2:height', 1),
#   ('name:new', 1),
#   ('recycling:books', 1),
#   ('lang:ga', 1),
#   ('supermarket', 1),
#   ('name:sr-Latn', 1),
#   ('key', 1),
#   ('name:mrj', 1),
#   ('oneway:motorcycle', 1),
#   ('name:hsb', 1),
#   ('name:bm', 1),
#   ('name:fo', 1),
#   ('capital_city', 1),
#   ('name:kab', 1),
#   ('osref', 1),
#   ('seamark:light:2:sector_start', 1),
#   ('community', 1),
#   ('charging_station:capacity', 1),
#   ('name:or', 1),
#   ('conference', 1),
#   ('name:tzl', 1),
#   ('operator:pl', 1),
#   ('garden:type', 1),
#   ('service:fax', 1),
#   ('seamark:light:2:range', 1),
#   ('name:zh_pinyin', 1),
#   ('gap', 1),
#   ('name:oc', 1),
#   ('name:to', 1),
#   ('name:dv', 1),
#   ('seamark:topmark:shape', 1),
#   ('fuel:biogas', 1),
#   ('parking_space', 1),
#   ('name:bar', 1),
#   ('childcare', 1),
#   ('name:yo', 1),
#   ('addr:housenumber:source', 1),
#   ('maxspeed_1', 1),
#   ('name:koi', 1),
#   ('site', 1),
#   ('recycling:fridge_and_freezer', 1),
#   ('fuel:octane_98', 1),
#   ('ISO3166-1:alpha3', 1),
#   ('name:haw', 1),
#   ('party', 1),
#   ('status', 1),
#   ('website_description:source_data', 1),
#   ('craft_beer', 1),
#   ('name:ace', 1),
#   ('garden:style', 1),
#   ('name:io', 1),
#   ('name:fur', 1),
#   ('name:vep', 1),
#   ('traffic', 1),
#   ('name:wuu', 1),
#   ('outdoor', 1),
#   ('name:sco', 1),
#   ('oneway:psv', 1),
#   ...])

# %% [markdown]
# ## 2 Audit tags

# %%
import re

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

# %%
def key_type(element, keys):
    if element.tag == "tag":
        if lower.search(element.attrib['k']):
            keys['lower'] += 1
        elif lower_colon.search(element.attrib['k']):
            keys['lower_colon'] += 1
        elif problemchars.search(element.attrib['k']):
            keys['problemchars'] += 1
        else:
            keys['other'] += 1
    return keys

# %%
def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

# %%
keys = process_map(filename)
pprint.pprint(keys)
# Out:
# {'lower': 472762, 'lower_colon': 257464, 'other': 34386, 'problemchars': 0}

# %% [markdown]
# ## 3 Check out user contributions

# %%
def process_map(filename):
    users = {}
    for _, element in ET.iterparse(filename):
        if 'user' in element.attrib.keys():
            if element.attrib['user'] not in users.keys():
                users[element.attrib['user']] = 1
            else:
                users[element.attrib['user']] += 1
    return users

# %%
users = process_map(filename)
users_sorted = sorted(users.items(), key=lambda t: t[1], reverse = True)
print "There are " + str(len(users)) + " contributors to the dataset."
print "The top contributors are:"
pprint.pprint(users_sorted[0:10])
# Out:
# There are 1122 contributors to the dataset.
# The top contributors are:
# [('Nick Burrett', 236906),
#  ('mackerski', 183786),
#  ('brianh', 156316),
#  ('Dafo43', 150926),
#  ('Conormap', 64014),
#  ('Ignobilis', 52864),
#  ('VictorIE', 48672),
#  ('Autarch', 21808),
#  ('wigs', 20793),
#  ('Blazejos', 19574)]

# %% [markdown]
# ## 4 Audit Addresses

# %% [markdown]
# ### 4.1 Audit Street Addresses

# %% [markdown]
# #### 4.1.1 Import and predefine methods and variables

# %%
from collections import defaultdict

# %%
get_last_word = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Centre", "Close", "Crescent", "Grove", "Garden", "Gardens", "Green",
            "Heights", "Hill", "Lawn", "Lawns", "Park", "Quay", "Row", "Terrace", "Wood", "Way", "Walk", "Upper",
            "Lower", "North", "South", "East", "West"]

mapping = { "St.": "Street",
            "St": "Street",
            "Sreet": "Street",
            "Rd.": "Road",
            "Ave": "Avenue",
            "Avevnue": "Avenue",
            "Center": "Centre",
            "Cente": "Centre"
            }

# %% [markdown]
# #### 4.1.2 Helper functions for Street Address Audit

# %%
def audit_street_type(street_types, street_name):
    m = get_last_word.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

# %%
def is_street_name(elem):
    return (elem.attrib['k'] == "adr:street")

# %%
def audit_streets(filename):
    osm_file = open(filename, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types

# %%
def update_streets(name, mapping, st_types):
    
    # Loop through dictionary and correct pre-defined mistakes:
    for st_type, value_set in st_types.iteritems():
        if name in value_set:
            # Ensure all words start with a capital letter: "lord edward's st" -> "Lord Edward'S St"
            name = name.title()
    
            # Rewrite "'S" to "'s": "Lord Edward'S St" -> "Lord Edward's St"
            name = re.sub('\'S', '\'s', name)
            
            # Correct common mistake from mapping dict: "Lord Edward's St -> "Lord Edward's Street"
            for key in mapping:       
                if name.find(key) != -1:
                    name = name[:name.find(key)]+mapping[key]+name[name.find(key)+len(str(key)):]
    return name

# %% [markdown]
# #### 4.1.3 Street Address Audit

# %%
st_types = audit_streets(filename)
pprint.pprint(dict(st_types))
# Out:
# {'1-13': set(['The Rise 1-13']),
#  '1-9': set(['Manor Court 1-9']),
#  '10-21': set(['Manor Court 10-21']),
#  '14-28': set(['The Rise 14-28']),
#  '26': set(['26']),
#  '27-31': set(['Supple Park 27-31']),
#  '32-39': set(['Supple Park 32-39']),
#  '4': set(['Serpentine Avenue, Ballsbridge, Dublin 4']),
#  '40-44': set(['Supple Park 40-44']),
#  '48-': set(['Supple Park 48-']),
#  'Abbey': set(['Fonthill Abbey', "Mary's Abbey", 'Seachnall Abbey']),
#  'Airport': set(['Dublin Airport']),
#  'Albany': set(['Mount Albany']),
#  'Alders': set(['The Alders']),
#  'Alley': set(['Copper Alley',
#                'Crown Alley',
#                'Lamb Alley',
#                'Smock Alley',
#                "Swift's Alley",
#                'Thundercut Alley']),
#  'Apartments': set(['Shelbourne Park Apartments']),
#  'Archerswood': set(['Archerswood']),
#  'Ardglas': set(['Ardglas']),
#  'Arundel': set(['Arundel']),
#  'Ashurst': set(['Ashurst']),
#  'Aspencourt': set(['Aspencourt']),
#  'Ave': set(['First Ave', 'Griffith Ave', 'Spruce Ave']),
#  'Avevnue': set(['Kill Avevnue']),
#  'Avonmore': set(['Avonmore']),
#  'Ballycoolin': set(['Orion Business Centre, Ballycoolin']),
#  'Bank': set(['Hazelwood Bank', 'Royal Canal Bank', 'Willow Bank']),
#  'Bar': set(['Temple Bar']),
#  'Barnacullia': set(['Barnacullia']),
#  'Bay': set(['Botany Bay']),
#  'Bayview': set(['Bayview']),
#  'Beeches': set(['The Beeches']),
#  'Beechview': set(['Beechview']),
#  'Belfield': set(['Belfield']),
#  'Bellevue': set(['Bellevue']),
#  'Belmont': set(['Belmont']),
#  "Benedict's": set(["St Benedict's"]),
#  'Bervstede': set(['Bervstede']),
#  'Biscayne': set(['Biscayne']),
#  'Blackpitts': set(['Blackpitts']),
#  'Blanchardstown': set(['Unit 2, Rosemount Business Park, Blanchardstown']),
#  'Bohernabreena': set(['Bohernabreena']),
#  'Brae': set(['Eaton Brae']),
#  'Brambles': set(['The Brambles']),
#  'Bridge': set(['Louisa Bridge']),
#  'Broadstone': set(['Broadstone']),
#  'Brook': set(['Castleknock Brook', 'Lambs Brook']),
#  'Brookdene': set(['Brookdene']),
#  'Brookfield': set(['Brookfield']),
#  'Brooklawn': set(['Brooklawn']),
#  'Brookside': set(['Brookside']),
#  'Brugh': set(['Clon Brugh']),
#  'Buildings': set(['Glasthule Buildings']),
#  'Bypass': set(['Dundrum Bypass', 'Palmerston Bypass', 'Tallaght Bypass']),
#  'Cairn': set(['Cois Cairn']),
#  'Cairnfort': set(['Cairnfort']),
#  'Campus': set(['Airport Business Campus', 'Swords Business Campus']),
#  'Cappaghmore': set(['Cappaghmore']),
#  'Carraiglea': set(['Carraiglea']),
#  'Carrigwood': set(['Carrigwood']),
#  'Castle': set(['Dublin Castle', 'Malahide Castle', 'Roebuck Castle']),
#  'Castlebrook': set(['Castlebrook']),
#  'Castlelands': set(['Castlelands']),
#  'Castletown': set(['Castletown']),
#  'Cedarmount': set(['Cedarmount']),
#  'Cedars': set(['The Cedars']),
#  'Cente': set(['Charlestown Shopping Cente']),
#  'Center': set(['Omni Center']),
#  'Chapelton': set(['Chapelton']),
#  'Chase': set(['Glencairn Chase',
#                'Griffeen Glen Chase',
#                'Moy Glas Chase',
#                'Riverwood Chase']),
#  'Cherries': set(['The Cherries']),
#  'Cherrygarth': set(['Cherrygarth']),
#  'Cherrywood': set(['Cherrywood']),
#  'Churchfields': set(['Churchfields']),
#  'Churchlands': set(['Churchlands']),
#  'Citywest': set(['Kingswood Avenue, Citywest']),
#  'Clanmawr': set(['Clanmawr']),
#  'Cliffs': set(['Shanganagh Cliffs']),
#  'Clonasleigh': set(['Clonasleigh']),
#  'Coille': set(['Barr Na Coille']),
#  'College': set(['Trinity College']),
#  'Complex': set(['Aldi Complex']),
#  'Coolevin': set(['Coolevin']),
#  'Coolkill': set(['Coolkill']),
#  'Coolnahinch': set(['Coolnahinch']),
#  'Coolnevaun': set(['Coolnevaun']),
#  'Coombe': set(['The Coombe']),
#  'Copse': set(['Belarmine Copse',
#                'Bellvue Copse',
#                'Connawood Copse',
#                'Glencairn Copse',
#                'Monastery Gate Copse',
#                'Riverwood Copse',
#                "Saint Helier's Copse",
#                'The Copse']),
#  'Cornelscourt': set(['New Cornelscourt']),
#  'Corner': set(["Dunphy's Corner"]),
#  'Cornmarket': set(['Cornmarket']),
#  'Cottage': set(['Frankfort Cottage']),
#  'Cottages': set(['Ballyedmonduff Cottages',
#                   'Bank Side Cottages',
#                   'Bohernabreena Cottages',
#                   'Dodsboro Cottages',
#                   'Emerald Cottages',
#                   'Estate Cottages',
#                   'Foxside Cottages',
#                   'Glenamuck Cottages',
#                   'Golden Ball Cottages',
#                   "Harold's Cross Cottages",
#                   'Jamestown Cottages',
#                   'Kilternan Cottages',
#                   'Kirwan Street Cottages',
#                   'Moss Cottages',
#                   'Mounttown Cottages',
#                   'Pembroke Cottages',
#                   'Priestfield Cottages',
#                   'Railway Cottages',
#                   'Richmond Cottages',
#                   'Riverside Cottages',
#                   'Saint Brocs Cottages',
#                   'Shamrock Cottages',
#                   'Stradbrook Cottages',
#                   'Wayside Cottages',
#                   'Woodside Cottages']),
#  'Courtyard': set(['Courtyard', 'The Courtyard']),
#  'Cove': set(['Clearwater Cove', 'Rockwell Cove']),
#  'Cross': set(['Lambs Cross', "Newland's Cross", 'Newtown Cross']),
#  'Crossing': set(["Ferryman's Crossing"]),
#  'Crowfall': set(['Crowfall']),
#  'Dale': set(['Castlegrange Dale',
#               'Castleknock Dale',
#               'Corbawn Dale',
#               'Glencairn Dale',
#               'Glenshane Dale',
#               'Griffeen Glen Dale',
#               'Haydens Park Dale',
#               'Laverna Dale',
#               'Moy Glas Dale',
#               'Orpen Dale']),
#  'Dales': set(['Rathmichael Dales']),
#  'Daleview': set(['Daleview']),
#  'Dalymount': set(['Dalymount']),
#  'Demesne': set(['Enniskerry Demesne']),
#  'Dene': set(['Elm Dene']),
#  'District': set(['Pembroke District']),
#  'Dock': set(['Charlotte Quay Dock']),
#  'Donghmede': set(['Newbrook Road, Donghmede']),
#  'Downs': set(['Ardilea Downs',
#                'Beaupark Downs',
#                'Belfield Downs',
#                'Carriglea Downs',
#                'Castleknock Downs',
#                'Cowper Downs',
#                'Harlech Downs',
#                'Hillcrest Downs',
#                'Monksfield Downs',
#                'Oak Downs',
#                'Roebuck Downs',
#                'Sandyford Downs',
#                'Sutton Downs',
#                'Warrenstown Downs',
#                'Woodford Downs']),
#  'Drumahill': set(['Drumahill']),
#  'Dundrum': set(['Balally, Dundrum']),
#  'Ellesmere': set(['Ellesmere']),
#  'Elmfield': set(['Elmfield']),
#  'Elms': set(['Castleknock Elms', 'The Elms']),
#  'End': set(['Cowper Mews End']),
#  'Estate': set(['Airways Industrial Estate',
#                 'Cherry Orchard Industrial Estate',
#                 'Darling Estate',
#                 'IDA Business Park, Ballycoolin Industrial Estate',
#                 'Killinarden Estate',
#                 'Mount Anthony Estate',
#                 'North Park Industrial Estate',
#                 'Rosemount Estate']),
#  'Extension': set(['Butterfield Close Extension']),
#  'Fairview': set(['Fairview']),
#  'Fairways': set(['Fairways', 'The Fairways']),
#  'Farm': set(['Monkstown Farm']),
#  'Fernbrook': set(['Fernbrook']),
#  'Fitzpatrick': set(['A94 Pocock or A84 Fitzpatrick']),
#  'Fleurville': set(['Fleurville']),
#  'Fosterbrook': set(['Fosterbrook']),
#  'Fosters': set(['The Fosters']),
#  'Friarsland': set(['Friarsland']),
#  'Gables': set(['The Gables']),
#  'Garth': set(['Bramley Garth',
#                'Glen Garth',
#                'Glencairn Garth',
#                'Warrenstown Garth']),
#  'Gate': set(['Cloister Gate', 'College Gate', 'Monkstown Gate']),
#  'Gates': set(['Merrion Gates']),
#  'Glade': set(['Allendale Glade',
#                'Bayview Glade',
#                'Castleknock Glade',
#                'Coppinger Glade',
#                'Glencairn Glade',
#                'Haydens Park Glade',
#                'Orwell Park Glade',
#                'Roselawn Glade']),
#  'Glasnevin': set(['Harts Corner, Finglas Road, Glasnevin']),
#  'Glen': set(['Bayview Glen',
#               'Glencairn Glen',
#               'Oldbridge Glen',
#               'Orwell Park Glen',
#               'Riverwood Glen',
#               'The Glen']),
#  'Gleneaston': set(['Gleneaston']),
#  'Glenview': set(['Glenview']),
#  'Grange': set(['Castleknock Grange', 'The Grange']),
#  'Grangefield': set(['Grangefield']),
#  'Great': set(['Ship Street Great']),
#  'Greenlands': set(['Greenlands']),
#  'Greygates': set(['Greygates']),
#  'Hall': set(['Belarmine Hall',
#               'Chancery Hall',
#               'Custom Hall',
#               'Gleanard Hall',
#               'Glenageary Hall',
#               'Granite Hall',
#               'Lansdowne Hall',
#               'Oriel Hall',
#               'Priory Hall',
#               'Stradbrook Hall',
#               'Wheaten Hall']),
#  'Harbour': set(['Custom House Harbour', 'Portobello Harbour', 'The Harbour']),
#  'Harvard': set(['Harvard']),
#  'Haven': set(['Beechfield Haven']),
#  'Hazelbrook': set(['Hazelbrook']),
#  'Hazelwood': set(['Hazelwood']),
#  'Heath': set(['Ash Park Heath',
#                'Bramley Heath',
#                'Castleview Heath',
#                'Glencairn Heath',
#                'Killiney Heath',
#                'Manor Heath',
#                'Stillorgan Heath']),
#  'Heathfield': set(['Heathfield']),
#  'Heidleberg': set(['Heidleberg']),
#  'Hillcrest': set(['Hillcrest']),
#  'Holywell': set(['Holywell']),
#  'House': set(['Belmont House',
#                'Eirpage House',
#                'Grove House',
#                'Millview House',
#                'Peadar Kearney House']),
#  'Innismore': set(['Innismore']),
#  'Island': set(["Usher's Island"]),
#  'Janeville': set(['Janeville']),
#  'Kilbride': set(['Manor Kilbride']),
#  'Killegar': set(['Killegar']),
#  'Kilmainham': set(['South Circular Road, Kilmainham']),
#  'Knocknagow': set(['Knocknagow']),
#  'Knocknashee': set(['Knocknashee']),
#  'Laraghcon': set(['Laraghcon']),
#  'Laurels': set(['Castleknock Laurels']),
#  'Laurelton': set(['Laurelton']),
#  'Laurleen': set(['Laurleen']),
#  'Lehaunstown': set(['Lehaunstown']),
#  'Leopardstown': set(['Central Park, Leopardstown']),
#  'Little': set(['Longford Street Little', 'Mary Street Little']),
#  'Littlewood': set(['Littlewood']),
#  'Lodge': set(['Annaville Lodge',
#                'Emerald Lodge',
#                'Glenageary Lodge',
#                'Harcourt Lodge',
#                'Lansdowne Lodge',
#                'Talbot Lodge',
#                'Woodlands Lodge']),
#  'Lorcan': set(['Ard Lorcan']),
#  'Lotts': set(['North Lotts']),
#  'Louvain': set(['Louvain']),
#  'Mall': set(['Charlemont Mall',
#               'Charleville Mall',
#               'Drogheda Mall',
#               'The Mall']),
#  'Manor': set(['Ballybride Manor',
#                'Ballyolaf Manor',
#                'Beaufield Manor',
#                'Carpenterstown Manor',
#                'Carrick Manor',
#                'Carrickmines Manor',
#                'Clarinda Manor',
#                'Foxrock Manor',
#                'Kenilworth Manor',
#                'Montpelier Manor',
#                'Taney Manor']),
#  'Maples': set(['The Maples']),
#  'Mara': set(['Ard na Mara']),
#  'Market': set(['Camden Market', 'Castle Market', 'Clarendon Market']),
#  'Mart': set(['Marino Mart']),
#  'Maryland': set(['Maryland']),
#  'Mayfield': set(['Mayfield']),
#  'Mead': set(['Saint Thomas Mead']),
#  'Meadow': set(['Sleeping Meadow',
#                 'Sundale Meadow',
#                 'The Meadow',
#                 'Weston Meadow']),
#  'Meadowbank': set(['Meadowbank']),
#  'Meadowfield': set(['Meadowfield']),
#  'Meadows': set(['Beverton Meadows',
#                  'Castleknock Meadows',
#                  'Johns Bridge Meadows',
#                  'Littlepace Meadows',
#                  'Monksfield Meadows',
#                  'Russell Meadows',
#                  'Woodford Meadows']),
#  'Meath': set(['Piercetown, Dunboyne, Co. Meath']),
#  'Mews': set(['Burlington Mews',
#               'Church Mews',
#               'Cowper Mews',
#               "Flann O'Brien Mews",
#               'Garville Mews',
#               'Granitefield Mews',
#               'Herbert Park Mews',
#               'Hollywood Mews',
#               'Leeson Mews',
#               'Myross Mews',
#               'Observatory Mews',
#               'Orwell Mews',
#               'Strand Mews',
#               'The Mews',
#               'Winton Mews']),
#  'Middle': set(['Gardiner Street Middle']),
#  'Millstead': set(['Millstead']),
#  u'Mobhi\xa0Road': set([u'Saint Mobhi\xa0Road']),
#  'Moorefield': set(['Moorefield']),
#  'Moorings': set(['The Moorings']),
#  'Mount': set(['Foxrock Mount']),
#  'Moyville': set(['Moyville']),
#  'Newmarket': set(['Newmarket']),
#  'Newtownsmith': set(['Newtownsmith']),
#  'Norwood': set(['Norwood']),
#  'Nouth': set(['Bayside Boulevard Nouth']),
#  'Oakdene': set(['Oakdene']),
#  'Oaks': set(['Castleknock Oaks',
#               'Glencairn Oaks',
#               'Leopardstown Oaks',
#               'The Oaks']),
#  'Orchard': set(['Beverton Orchard', 'Butterfield Orchard', 'The Orchard']),
#  'Paddock': set(['Grove Paddock']),
#  'Pakenham': set(['Pakenham']),
#  'Parade': set(['Bessborough Parade',
#                 'Charlemont Parade',
#                 'Connaught Parade',
#                 'Grand Parade',
#                 'Greencastle Parade',
#                 'Kingsland Parade',
#                 'Marine Parade',
#                 'Mountpleasant Parade',
#                 'Poppintree Parade',
#                 'Rear Summerhill Parade',
#                 'Richmond Parade',
#                 'Seafort Parade',
#                 'Summerhill Parade',
#                 'Sundale Parade',
#                 'Tivoli Parade',
#                 'Turlough Parade']),
#  'Parklands': set(['Parklands']),
#  'Parknasilloge': set(['Parknasilloge']),
#  'Parkvale': set(['Parkvale']),
#  'Parkview': set(['Parkview']),
#  'Pimlico': set(['Pimlico']),
#  'Pinar': set(['El Pinar']),
#  'Pinehurst': set(['Pinehurst']),
#  'Pines': set(['The Pines']),
#  'Pinewood': set(['Pinewood']),
#  'Plaza': set(['Belarmine Plaza', 'Grand Canal Plaza', 'Tyrrelstown Plaza']),
#  'Pleasant': set(['Old Mount Pleasant']),
#  'Point': set(['Sandycove Point']),
#  'Poplars': set(['The Poplars']),
#  'Powerscourt': set(['Powerscourt']),
#  'Princeton': set(['Princeton']),
#  'Ralahine': set(['Ralahine']),
#  'Ranelagh': set(['Ranelagh']),
#  'Rathcoole': set(['N7 Naas Road, Rathcoole']),
#  'Rd.': set(['Strand Rd.']),
#  'Rectory': set(['The Rectory']),
#  'Rest': set(["Angler's Rest"]),
#  'Rhodaville': set(['Rhodaville']),
#  'Richmond': set(['Richmond']),
#  'Richview': set(['Richview']),
#  'Rise': set(['Alpine Rise',
#               'Bayview Rise',
#               'Beverton Rise',
#               'Broadford Rise',
#               'Carriglea Rise',
#               'Castleknock Rise',
#               'Colthurst Rise',
#               'Cruagh Rise',
#               'Ellensborough Rise',
#               'Ferncarrig Rise',
#               'Glencairn Rise',
#               'Killakee Rise',
#               'Kingston Rise',
#               'Leopardstown Rise',
#               'Manor Rise',
#               'Mount Eagle Rise',
#               'Oak Rise',
#               'Orpen Rise',
#               'Orwell Park Rise',
#               'Pinebrook Rise',
#               'Portersgate Rise',
#               'Sandyford Hall Rise',
#               'Sarto Rise',
#               'Taney Rise',
#               'The Rise',
#               'Warrenstown Rise',
#               'Woodford Rise']),
#  'Roafd': set(['Old Dublin Roafd']),
#  'Rockbrook': set(['Rockbrook']),
#  'Rockfield': set(['Rockfield']),
#  'Rocwood': set(['Rocwood']),
#  'Roseacre': set(['Roseacre']),
#  'Rowanbyrn': set(['Rowanbyrn']),
#  'Rubrics': set(['The Rubrics']),
#  'Rushbrook': set(['Rushbrook']),
#  'Salamanca': set(['Salamanca']),
#  'Sandford': set(['Mount Sandford']),
#  'Seafield': set(['Seafield']),
#  'Seapark': set(['Seapark']),
#  'Shee': set(['Cluain Shee']),
#  'Sloperton': set(['Sloperton']),
#  'Slopes': set(['The Slopes']),
#  'Smol': set(['Gleann na Smol']),
#  'Sommerville': set(['Sommerville']),
#  'Sorbonne': set(['Sorbonne']),
#  'Southdene': set(['Southdene']),
#  'Sreet': set(['Parliament Sreet']),
#  'St': set(['Aungier St', 'Harcourt St']),
#  'Stables': set(['The Stables']),
#  'Stoneybatter': set(['Stoneybatter']),
#  'Strand': set(['Fairview Strand', 'Merrion Strand']),
#  'Summerhill': set(['Summerhill']),
#  'Sunnybank': set(['Sunnybank']),
#  'Sycamores': set(['The Sycamores']),
#  'Thicket': set(['Glencairn Thicket']),
#  'Third': set(['Middle Third']),
#  'Thorpe': set(['Wood Thorpe']),
#  'Torcaill': set(['Torcaill']),
#  'Treesdale': set(['Treesdale']),
#  'Ullardmor': set(['Ullardmor']),
#  'Vale': set(['Ballyogan Vale',
#               'Belarmine Vale',
#               'Brighton Vale',
#               'Castleknock Vale',
#               'Grangebrook Vale',
#               'Griffeen Glen Vale',
#               'Meadow Vale',
#               'Shanganagh Vale',
#               'Warrenstown Vale',
#               'Willow Vale',
#               'Yellow Meadows Vale']),
#  'Valley': set(['Business Campus, Liffey Valley',
#                 'Dargle Valley',
#                 'Monkstown Valley']),
#  'Vergemount': set(['Vergemount']),
#  'View': set(['Bramley View',
#               'Carriglea View',
#               'Castleknock View',
#               'Corkagh View',
#               'Court View',
#               'Dundrum View',
#               'Elm View',
#               'Glencairn View',
#               'Grange Park View',
#               'Griffeen Glen View',
#               'Haydens Park View',
#               'Hazelwood View',
#               'Highland View',
#               'Hillcrest View',
#               'Island View',
#               'Kelston View',
#               'Killakee View',
#               'Kingston View',
#               'Meadow View',
#               'Mount Eagle View',
#               'Oldbridge View',
#               'Orwell View',
#               'Roselawn View',
#               'Sandyford Hall View',
#               'Sycamore View',
#               'The View',
#               'Warrenstown View']),
#  'Villa': set(['Anna Villa', 'Island Villa']),
#  'Village': set(['Coolock Village',
#                  'Cowper Village',
#                  'Sandyford Village',
#                  'The Village']),
#  'Villas': set(['Ard Lorcan Villas',
#                 'Athlumney Villas',
#                 'Auburn Villas',
#                 'Belton Park Villas',
#                 'Bentley Villas',
#                 'Clare Park Villas',
#                 'Eblana Villas',
#                 'Eden Villas',
#                 'Esker Villas',
#                 'Great Western Villas',
#                 'Harcourt Villas',
#                 'Hazel Villas',
#                 'Home Villas',
#                 'Homelawn Villas',
#                 'Maretimo Villas',
#                 'Marley Villas',
#                 "McCabe's Villas",
#                 'Monastery Gate Villas',
#                 'Mountain Villas',
#                 'Northbrook Villas',
#                 'Park Villas',
#                 'Patrician Villas',
#                 'Ramleh Villas',
#                 'Rathgar Villas',
#                 'Rathmore Villas',
#                 'Richview Villas',
#                 "Saint Helen's Villas",
#                 "Saint Patrick's Villas",
#                 "Smyth's Villas",
#                 "St. Jospeh's Villas",
#                 'Stepaside Villas',
#                 'Sundale Villas',
#                 'Sydenham Villas',
#                 'Windsor Villas']),
#  'Wansdowne': set(['Wansdowne']),
#  'Ward': set(['The Ward']),
#  'Waterside': set(['Waterside']),
#  'Weirview': set(['Weirview']),
#  'Well': set(["St Domhnach's Well"]),
#  'Wesbury': set(['Wesbury']),
#  'Westhaven': set(['Westhaven']),
#  'Wilfield': set(['Wilfield']),
#  'Willows': set(['The Willows']),
#  'Wingfield': set(['Wingfield']),
#  'Woodlands': set(['Castletown The Woodlands']),
#  'Woodpark': set(['Woodpark']),
#  'Woods': set(['Highthorn Woods', 'Palmerstown Woods']),
#  'Woodside': set(['Woodside']),
#  'Woodview': set(['Woodview']),
#  'Yale': set(['Yale']),
#  'Yard': set(['Station Yard']),
#  'castletown': set(['The Drive, castletown']),
#  'heights': set(['Ballinclea heights', 'The Rise,Belgard heights']),
#  'lane': set(['Hanbury lane', "Warner's lane"]),
#  'residential': set(['residential']),
#  'road': set(['Novara road']),
#  'st': set(['lord edward st']),
#  'street': set(['o connell street'])}

# %% [markdown]
# #### 4.1.3 Street Address Update Function Test

# %%
for st_type, ways in st_types.iteritems():
    for name in ways:
        better_name = update_streets(name, mapping, st_type)
        print name, "=>", better_name
# Out:
# The Gables => The Gables
# Mount Albany => Mount Albany
# Westhaven => Westhaven
# Brooklawn => Brooklawn
# Estate Cottages => Estate Cottages
# Kilternan Cottages => Kilternan Cottages
# Jamestown Cottages => Jamestown Cottages
# Foxside Cottages => Foxside Cottages
# Emerald Cottages => Emerald Cottages
# Shamrock Cottages => Shamrock Cottages
# Mounttown Cottages => Mounttown Cottages
# Saint Brocs Cottages => Saint Brocs Cottages
# Ballyedmonduff Cottages => Ballyedmonduff Cottages
# Dodsboro Cottages => Dodsboro Cottages
# Stradbrook Cottages => Streetradbrook Cottages
# Bohernabreena Cottages => Bohernabreena Cottages
# Bank Side Cottages => Bank Side Cottages
# Riverside Cottages => Riverside Cottages
# Priestfield Cottages => Priestfield Cottages
# Golden Ball Cottages => Golden Ball Cottages
# Harold's Cross Cottages => Harold's Cross Cottages
# Pembroke Cottages => Pembroke Cottages
# Glenamuck Cottages => Glenamuck Cottages
# Wayside Cottages => Wayside Cottages
# Railway Cottages => Railway Cottages
# Woodside Cottages => Woodside Cottages
# Moss Cottages => Moss Cottages
# Kirwan Street Cottages => Kirwan Streetreet Cottages
# Richmond Cottages => Richmond Cottages
# Rushbrook => Rushbrook
# Cornmarket => Cornmarket
# The Alders => The Alders
# Bervstede => Bervstede
# Gleann na Smol => Gleann Na Smol
# Churchfields => Churchfields
# Rockbrook => Rockbrook
# The Rise 1-13 => The Rise 1-13
# Wansdowne => Wansdowne
# Emerald Lodge => Emerald Lodge
# Lansdowne Lodge => Lansdowne Lodge
# Glenageary Lodge => Glenageary Lodge
# Talbot Lodge => Talbot Lodge
# Harcourt Lodge => Harcourt Lodge
# Annaville Lodge => Annaville Lodge
# Woodlands Lodge => Woodlands Lodge
# College Gate => College Gate
# Cloister Gate => Cloister Gate
# Monkstown Gate => Monkstown Gate
# Leopardstown Oaks => Leopardstown Oaks
# Glencairn Oaks => Glencairn Oaks
# The Oaks => The Oaks
# Castleknock Oaks => Castleknock Oaks
# Crowfall => Crowfall
# Moyville => Moyville
# Sommerville => Sommerville
# Blackpitts => Blackpitts
# 26 => 26
# Herbert Park Mews => Herbert Park Mews
# Strand Mews => Streetrand Mews
# Hollywood Mews => Hollywood Mews
# Burlington Mews => Burlington Mews
# Orwell Mews => Orwell Mews
# Granitefield Mews => Granitefield Mews
# Myross Mews => Myross Mews
# The Mews => The Mews
# Church Mews => Church Mews
# Cowper Mews => Cowper Mews
# Flann O'Brien Mews => Flann O'Brien Mews
# Observatory Mews => Observatory Mews
# Garville Mews => Garville Mews
# Winton Mews => Winton Mews
# Leeson Mews => Leeson Mews
# Central Park, Leopardstown => Central Park, Leopardstown
# residential => Residential
# Ellesmere => Ellesmere
# Rockwell Cove => Rockwell Cove
# Clearwater Cove => Clearwater Cove
# Bellevue => Bellevue
# Meadowbank => Meadowbank
# Harvard => Harvard
# Arundel => Arundel
# Charlestown Shopping Cente => Charlestown Shopping Centre
# Frankfort Cottage => Frankfort Cottage
# Fleurville => Fleurville
# Beechfield Haven => Beechfield Haven
# Monastery Gate Copse => Monastery Gate Copse
# Riverwood Copse => Riverwood Copse
# Glencairn Copse => Glencairn Copse
# Connawood Copse => Connawood Copse
# Saint Helier's Copse => Saint Helier's Copse
# Belarmine Copse => Belarmine Copse
# Bellvue Copse => Bellvue Copse
# The Copse => The Copse
# Laurleen => Laurleen
# The Beeches => The Beeches
# Mayfield => Mayfield
# Temple Bar => Temple Bar
# Supple Park 27-31 => Supple Park 27-31
# Elmfield => Elmfield
# Castleknock Laurels => Castleknock Laurels
# Kill Avevnue => Kill Avenuenue
# Newtownsmith => Newtownsmith
# Ralahine => Ralahine
# Parknasilloge => Parknasilloge
# Louvain => Louvain
# Supple Park 32-39 => Supple Park 32-39
# Glenview => Glenview
# Beechview => Beechview
# Castletown The Woodlands => Castletown The Woodlands
# Coolnahinch => Coolnahinch
# Newbrook Road, Donghmede => Newbrook Road, Donghmede
# Holywell => Holywell
# Seafield => Seafield
# Knocknagow => Knocknagow
# Island Villa => Island Villa
# Anna Villa => Anna Villa
# Coolnevaun => Coolnevaun
# Old Dublin Roafd => Old Dublin Roafd
# Belmont => Belmont
# Fosterbrook => Fosterbrook
# Swift's Alley => Swift's Alley
# Lamb Alley => Lamb Alley
# Thundercut Alley => Thundercut Alley
# Crown Alley => Crown Alley
# Copper Alley => Copper Alley
# Smock Alley => Smock Alley
# New Cornelscourt => New Cornelscourt
# The Moorings => The Moorings
# Cois Cairn => Cois Cairn
# The Sycamores => The Sycamores
# Heathfield => Heathfield
# Barnacullia => Barnacullia
# Brookside => Brookside
# Dunphy's Corner => Dunphy's Corner
# The Elms => The Elms
# Castleknock Elms => Castleknock Elms
# Dalymount => Dalymount
# Treesdale => Treesdale
# Glencairn Chase => Glencairn Chase
# Moy Glas Chase => Moy Glas Chase
# Riverwood Chase => Riverwood Chase
# Griffeen Glen Chase => Griffeen Glen Chase
# Riverwood Glen => Riverwood Glen
# Bayview Glen => Bayview Glen
# Glencairn Glen => Glencairn Glen
# Orwell Park Glen => Orwell Park Glen
# Oldbridge Glen => Oldbridge Glen
# The Glen => The Glen
# Vergemount => Vergemount
# Longford Street Little => Longford Streetreet Little
# Mary Street Little => Mary Streetreet Little
# Weston Meadow => Weston Meadow
# Sleeping Meadow => Sleeping Meadow
# Sundale Meadow => Sundale Meadow
# The Meadow => The Meadow
# Cowper Mews End => Cowper Mews End
# Ard na Mara => Ard Na Mara
# Pembroke District => Pembroke District
# Moorefield => Moorefield
# The Fosters => The Fosters
# Supple Park 48- => Supple Park 48-
# Roseacre => Roseacre
# The Cherries => The Cherries
# Marino Mart => Marino Mart
# Bohernabreena => Bohernabreena
# o connell street => O Connell Streetreet
# Angler's Rest => Angler's Rest
# Tallaght Bypass => Tallaght Bypass
# Palmerston Bypass => Palmerston Bypass
# Dundrum Bypass => Dundrum Bypass
# Glencairn Garth => Glencairn Garth
# Warrenstown Garth => Warrenstown Garth
# Glen Garth => Glen Garth
# Bramley Garth => Bramley Garth
# Manor Court 10-21 => Manor Court 10-21
# Maryland => Maryland
# Strand Rd. => Streetrand Road
# Rathmichael Dales => Rathmichael Dales
# Carraiglea => Carraiglea
# Glasthule Buildings => Glasthule Buildings
# Butterfield Close Extension => Butterfield Close Extension
# Archerswood => Archerswood
# Stoneybatter => Streetoneybatter
# Manor Rise => Manor Rise
# Castleknock Rise => Castleknock Rise
# Bayview Rise => Bayview Rise
# Leopardstown Rise => Leopardstown Rise
# Ferncarrig Rise => Ferncarrig Rise
# Cruagh Rise => Cruagh Rise
# Beverton Rise => Beverton Rise
# Oak Rise => Oak Rise
# The Rise => The Rise
# Orwell Park Rise => Orwell Park Rise
# Glencairn Rise => Glencairn Rise
# Alpine Rise => Alpine Rise
# Orpen Rise => Orpen Rise
# Portersgate Rise => Portersgate Rise
# Sandyford Hall Rise => Sandyford Hall Rise
# Mount Eagle Rise => Mount Eagle Rise
# Pinebrook Rise => Pinebrook Rise
# Kingston Rise => Kingston Rise
# Taney Rise => Taney Rise
# Ellensborough Rise => Ellensborough Rise
# Colthurst Rise => Colthurst Rise
# Warrenstown Rise => Warrenstown Rise
# Killakee Rise => Killakee Rise
# Broadford Rise => Broadford Rise
# Carriglea Rise => Carriglea Rise
# Woodford Rise => Woodford Rise
# Sarto Rise => Sarto Rise
# N7 Naas Road, Rathcoole => N7 Naas Road, Rathcoole
# Castleknock Meadows => Castleknock Meadows
# Beverton Meadows => Beverton Meadows
# Woodford Meadows => Woodford Meadows
# Johns Bridge Meadows => Johns Bridge Meadows
# Monksfield Meadows => Monksfield Meadows
# Littlepace Meadows => Littlepace Meadows
# Russell Meadows => Russell Meadows
# Courtyard => Courtyard
# The Courtyard => The Courtyard
# Chapelton => Chapelton
# Newmarket => Newmarket
# Ullardmor => Ullardmor
# The Ward => The Ward
# Parkview => Parkview
# Parliament Sreet => Parliament Streetreet
# Merrion Strand => Merrion Streetrand
# Fairview Strand => Fairview Streetrand
# Sloperton => Sloperton
# Powerscourt => Powerscourt
# Woodview => Woodview
# The Maples => The Maples
# Castlebrook => Castlebrook
# Butterfield Orchard => Butterfield Orchard
# The Orchard => The Orchard
# Beverton Orchard => Beverton Orchard
# Parkvale => Parkvale
# Grand Canal Plaza => Grand Canal Plaza
# Tyrrelstown Plaza => Tyrrelstown Plaza
# Belarmine Plaza => Belarmine Plaza
# The Fairways => The Fairways
# Fairways => Fairways
# Drogheda Mall => Drogheda Mall
# Charlemont Mall => Charlemont Mall
# The Mall => The Mall
# Charleville Mall => Charleville Mall
# Seapark => Seapark
# Grove Paddock => Grove Paddock
# Summerhill => Summerhill
# Mount Sandford => Mount Sandford
# Rhodaville => Rhodaville
# Broadstone => Broadstone
# Cluain Shee => Cluain Shee
# Tivoli Parade => Tivoli Parade
# Greencastle Parade => Greencastle Parade
# Richmond Parade => Richmond Parade
# Sundale Parade => Sundale Parade
# Bessborough Parade => Bessborough Parade
# Mountpleasant Parade => Mountpleasant Parade
# Seafort Parade => Seafort Parade
# Summerhill Parade => Summerhill Parade
# Grand Parade => Grand Parade
# Marine Parade => Marine Parade
# Kingsland Parade => Kingsland Parade
# Poppintree Parade => Poppintree Parade
# Rear Summerhill Parade => Rear Summerhill Parade
# Turlough Parade => Turlough Parade
# Connaught Parade => Connaught Parade
# Charlemont Parade => Charlemont Parade
# Churchlands => Churchlands
# Sandycove Point => Sandycove Point
# The Pines => The Pines
# Portobello Harbour => Portobello Harbour
# Custom House Harbour => Custom House Harbour
# The Harbour => The Harbour
# Aspencourt => Aspencourt
# Cherrygarth => Cherrygarth
# Highthorn Woods => Highthorn Woods
# Palmerstown Woods => Palmerstown Woods
# Clarendon Market => Clarendon Market
# Castle Market => Castle Market
# Camden Market => Camden Market
# Drumahill => Drumahill
# Brookdene => Brookdene
# Airport Business Campus => Airport Business Campus
# Swords Business Campus => Swords Business Campus
# Novara road => Novara Road
# Hazelbrook => Hazelbrook
# Laraghcon => Laraghcon
# Kingswood Avenue, Citywest => Kingswood Avenuenue, Citywest
# The Poplars => The Poplars
# The Rubrics => The Rubrics
# Usher's Island => Usher's Island
# The Coombe => The Coombe
# The Drive, castletown => The Drive, Castletown
# Sorbonne => Sorbonne
# Daleview => Daleview
# Richmond => Richmond
# Rocwood => Rocwood
# Weirview => Weirview
# Grangefield => Grangefield
# Coolkill => Coolkill
# Biscayne => Biscayne
# Carrigwood => Carrigwood
# Friarsland => Friarsland
# Waterside => Waterside
# Corbawn Dale => Corbawn Dale
# Glencairn Dale => Glencairn Dale
# Orpen Dale => Orpen Dale
# Laverna Dale => Laverna Dale
# Haydens Park Dale => Haydens Park Dale
# Glenshane Dale => Glenshane Dale
# Griffeen Glen Dale => Griffeen Glen Dale
# Castlegrange Dale => Castlegrange Dale
# Castleknock Dale => Castleknock Dale
# Moy Glas Dale => Moy Glas Dale
# Rowanbyrn => Rowanbyrn
# Wilfield => Wilfield
# Ard Lorcan => Ard Lorcan
# Salamanca => Salamanca
# Monkstown Farm => Monkstown Farm
# Clanmawr => Clanmawr
# Ardilea Downs => Ardilea Downs
# Sandyford Downs => Sandyford Downs
# Belfield Downs => Belfield Downs
# Beaupark Downs => Beaupark Downs
# Carriglea Downs => Carriglea Downs
# Castleknock Downs => Castleknock Downs
# Harlech Downs => Harlech Downs
# Monksfield Downs => Monksfield Downs
# Cowper Downs => Cowper Downs
# Hillcrest Downs => Hillcrest Downs
# Oak Downs => Oak Downs
# Sutton Downs => Sutton Downs
# Warrenstown Downs => Warrenstown Downs
# Woodford Downs => Woodford Downs
# Roebuck Downs => Roebuck Downs
# Cairnfort => Cairnfort
# Southdene => Southdene
# Castleknock Vale => Castleknock Vale
# Warrenstown Vale => Warrenstown Vale
# Shanganagh Vale => Shanganagh Vale
# Yellow Meadows Vale => Yellow Meadows Vale
# Griffeen Glen Vale => Griffeen Glen Vale
# Belarmine Vale => Belarmine Vale
# Meadow Vale => Meadow Vale
# Grangebrook Vale => Grangebrook Vale
# Willow Vale => Willow Vale
# Ballyogan Vale => Ballyogan Vale
# Brighton Vale => Brighton Vale
# The Rise,Belgard heights => The Rise,Belgard Heights
# Ballinclea heights => Ballinclea Heights
# Old Mount Pleasant => Old Mount Pleasant
# Laurelton => Laurelton
# Serpentine Avenue, Ballsbridge, Dublin 4 => Serpentine Avenuenue, Ballsbridge, Dublin 4
# Heidleberg => Heidleberg
# Omni Center => Omni Centre
# Louisa Bridge => Louisa Bridge
# Manor Kilbride => Manor Kilbride
# Avonmore => Avonmore
# Foxrock Mount => Foxrock Mount
# Torcaill => Torcaill
# Harcourt St => Harcourt Street
# Aungier St => Aungier Street
# South Circular Road, Kilmainham => South Circular Road, Kilmainham
# Sunnybank => Sunnybank
# Belfield => Belfield
# Northbrook Villas => Northbrook Villas
# Eblana Villas => Eblana Villas
# Saint Patrick's Villas => Saint Patrick's Villas
# Park Villas => Park Villas
# Patrician Villas => Patrician Villas
# Monastery Gate Villas => Monastery Gate Villas
# Athlumney Villas => Athlumney Villas
# Windsor Villas => Windsor Villas
# Saint Helen's Villas => Saint Helen's Villas
# Harcourt Villas => Harcourt Villas
# Hazel Villas => Hazel Villas
# Ard Lorcan Villas => Ard Lorcan Villas
# Mountain Villas => Mountain Villas
# Bentley Villas => Bentley Villas
# Sydenham Villas => Sydenham Villas
# Belton Park Villas => Belton Park Villas
# Great Western Villas => Great Western Villas
# McCabe's Villas => Mccabe's Villas
# Marley Villas => Marley Villas
# Sundale Villas => Sundale Villas
# Smyth's Villas => Smyth's Villas
# Auburn Villas => Auburn Villas
# Stepaside Villas => Streetepaside Villas
# Rathmore Villas => Rathmore Villas
# Home Villas => Home Villas
# Ramleh Villas => Ramleh Villas
# Eden Villas => Eden Villas
# Clare Park Villas => Clare Park Villas
# Rathgar Villas => Rathgar Villas
# Homelawn Villas => Homelawn Villas
# Richview Villas => Richview Villas
# St. Jospeh's Villas => Streetreet Jospeh's Villas
# Maretimo Villas => Maretimo Villas
# Esker Villas => Esker Villas
# Eaton Brae => Eaton Brae
# Bayview => Bayview
# Malahide Castle => Malahide Castle
# Roebuck Castle => Roebuck Castle
# Dublin Castle => Dublin Castle
# Supple Park 40-44 => Supple Park 40-44
# The Willows => The Willows
# Richview => Richview
# Killegar => Killegar
# Wesbury => Wesbury
# Millstead => Millstead
# Bayside Boulevard Nouth => Bayside Boulevard Nouth
# Eirpage House => Eirpage House
# Belmont House => Belmont House
# Millview House => Millview House
# Peadar Kearney House => Peadar Kearney House
# Grove House => Grove House
# Castletown => Castletown
# Ashurst => Ashurst
# The Brambles => The Brambles
# Pakenham => Pakenham
# Cedarmount => Cedarmount
# Aldi Complex => Aldi Complex
# Trinity College => Trinity College
# Greygates => Greygates
# Rockfield => Rockfield
# First Ave => First Avenue
# Spruce Ave => Spruce Avenue
# Griffith Ave => Griffith Avenue
# Castleknock Brook => Castleknock Brook
# Lambs Brook => Lambs Brook
# Coolevin => Coolevin
# Cappaghmore => Cappaghmore
# Gleneaston => Gleneaston
# Pimlico => Pimlico
# The Stables => The Streetables
# Castlelands => Castlelands
# Cherrywood => Cherrywood
# North Lotts => North Lotts
# Lambs Cross => Lambs Cross
# Newtown Cross => Newtown Cross
# Newland's Cross => Newland's Cross
# Wingfield => Wingfield
# Castleknock Grange => Castleknock Grange
# The Grange => The Grange
# The Rise 14-28 => The Rise 14-28
# Pinehurst => Pinehurst
# Piercetown, Dunboyne, Co. Meath => Piercetown, Dunboyne, Co. Meath
# Enniskerry Demesne => Enniskerry Demesne
# Parklands => Parklands
# Hazelwood => Hazelwood
# Station Yard => Streetation Yard
# The Slopes => The Slopes
# lord edward st => Lord Edward Street
# Seachnall Abbey => Seachnall Abbey
# Mary's Abbey => Mary's Abbey
# Fonthill Abbey => Fonthill Abbey
# Oakdene => Oakdene
# Norwood => Norwood
# Harts Corner, Finglas Road, Glasnevin => Harts Corner, Finglas Road, Glasnevin
# Janeville => Janeville
# Monkstown Valley => Monkstown Valley
# Business Campus, Liffey Valley => Business Campus, Liffey Valley
# Dargle Valley => Dargle Valley
# Ballyolaf Manor => Ballyolaf Manor
# Foxrock Manor => Foxrock Manor
# Beaufield Manor => Beaufield Manor
# Carpenterstown Manor => Carpenterstown Manor
# Taney Manor => Taney Manor
# Carrickmines Manor => Carrickmines Manor
# Montpelier Manor => Montpelier Manor
# Clarinda Manor => Clarinda Manor
# Kenilworth Manor => Kenilworth Manor
# Ballybride Manor => Ballybride Manor
# Carrick Manor => Carrick Manor
# Littlewood => Littlewood
# Princeton => Princeton
# Ranelagh => Ranelagh
# Unit 2, Rosemount Business Park, Blanchardstown => Unit 2, Rosemount Business Park, Blanchardstown
# Knocknashee => Knocknashee
# Charlotte Quay Dock => Charlotte Quay Dock
# Fairview => Fairview
# Orion Business Centre, Ballycoolin => Orion Business Centre, Ballycoolin
# Clon Brugh => Clon Brugh
# Brookfield => Brookfield
# Oriel Hall => Oriel Hall
# Wheaten Hall => Wheaten Hall
# Belarmine Hall => Belarmine Hall
# Glenageary Hall => Glenageary Hall
# Custom Hall => Custom Hall
# Lansdowne Hall => Lansdowne Hall
# Priory Hall => Priory Hall
# Gleanard Hall => Gleanard Hall
# Stradbrook Hall => Streetradbrook Hall
# Chancery Hall => Chancery Hall
# Granite Hall => Granite Hall
# Willow Bank => Willow Bank
# Royal Canal Bank => Royal Canal Bank
# Hazelwood Bank => Hazelwood Bank
# Innismore => Innismore
# Manor Court 1-9 => Manor Court 1-9
# Ship Street Great => Ship Streetreet Great
# Middle Third => Middle Third
# Greenlands => Greenlands
# St Domhnach's Well => Street Domhnach's Well
# A94 Pocock or A84 Fitzpatrick => A94 Pocock Or A84 Fitzpatrick
# St Benedict's => Street Benedict's
# Woodside => Woodside
# Orwell Park Glade => Orwell Park Glade
# Glencairn Glade => Glencairn Glade
# Castleknock Glade => Castleknock Glade
# Coppinger Glade => Coppinger Glade
# Bayview Glade => Bayview Glade
# Haydens Park Glade => Haydens Park Glade
# Allendale Glade => Allendale Glade
# Roselawn Glade => Roselawn Glade
# Manor Heath => Manor Heath
# Killiney Heath => Killiney Heath
# Ash Park Heath => Ash Park Heath
# Castleview Heath => Castleview Heath
# Stillorgan Heath => Streetillorgan Heath
# Glencairn Heath => Glencairn Heath
# Bramley Heath => Bramley Heath
# Wood Thorpe => Wood Thorpe
# Dublin Airport => Dublin Airport
# Saint Thomas Mead => Saint Thomas Mead
# Yale => Yale
# Ferryman's Crossing => Ferryman's Crossing
# Merrion Gates => Merrion Gates
# Botany Bay => Botany Bay
# Shanganagh Cliffs => Shanganagh Cliffs
# El Pinar => El Pinar
# Clonasleigh => Clonasleigh
# Bramley View => Bramley View
# Elm View => Elm View
# Meadow View => Meadow View
# Mount Eagle View => Mount Eagle View
# Kingston View => Kingston View
# Corkagh View => Corkagh View
# The View => The View
# Highland View => Highland View
# Sandyford Hall View => Sandyford Hall View
# Haydens Park View => Haydens Park View
# Castleknock View => Castleknock View
# Court View => Court View
# Sycamore View => Sycamore View
# Orwell View => Orwell View
# Glencairn View => Glencairn View
# Killakee View => Killakee View
# Dundrum View => Dundrum View
# Roselawn View => Roselawn View
# Grange Park View => Grange Park View
# Island View => Island View
# Hazelwood View => Hazelwood View
# Oldbridge View => Oldbridge View
# Warrenstown View => Warrenstown View
# Carriglea View => Carriglea View
# Griffeen Glen View => Griffeen Glen View
# Hillcrest View => Hillcrest View
# Kelston View => Kelston View
# Saint Mobhi Road => Saint Mobhi Road
# Hanbury lane => Hanbury Lane
# Warner's lane => Warner's Lane
# Glencairn Thicket => Glencairn Thicket
# The Cedars => The Cedars
# Airways Industrial Estate => Airways Industrial Estate
# Mount Anthony Estate => Mount Anthony Estate
# Rosemount Estate => Rosemount Estate
# Darling Estate => Darling Estate
# Killinarden Estate => Killinarden Estate
# IDA Business Park, Ballycoolin Industrial Estate => Ida Business Park, Ballycoolin Industrial Estate
# Cherry Orchard Industrial Estate => Cherry Orchard Industrial Estate
# North Park Industrial Estate => North Park Industrial Estate
# Shelbourne Park Apartments => Shelbourne Park Apartments
# Ardglas => Ardglas
# Meadowfield => Meadowfield
# Fernbrook => Fernbrook
# The Rectory => The Rectory
# Balally, Dundrum => Balally, Dundrum
# Lehaunstown => Lehaunstown
# Gardiner Street Middle => Gardiner Streetreet Middle
# Barr Na Coille => Barr Na Coille
# Hillcrest => Hillcrest
# Elm Dene => Elm Dene
# Sandyford Village => Sandyford Village
# Cowper Village => Cowper Village
# The Village => The Village
# Coolock Village => Coolock Village
# Woodpark => Woodpark
# Pinewood => Pinewood

# %% [markdown]
# ### 4.2 Postal Code Audit

# %% [markdown]
# #### 4.2.1 Helper functions for Postal Code Audit

# %%
def audit_pcode_type(pcode_types, pcode):
    if pcode:
        if pcode.startswith("Dublin"):
            pcode_types["Dublin"].add(pcode)
        elif pcode.startswith("D") and len(str(pcode)) in (2,3):
            pcode_types["D"].add(pcode)
        elif len(str(pcode)) == 2 and pcode[0] == "0":
            pcode_types["0"].add(pcode)
        elif len(pcode.split(" ")) > 1:
            pcode_types["Two items"].add(pcode)
        elif len(str(pcode)) > 2:
            pcode_types["too long"].add(pcode)
        elif len(str(pcode)) <= 2:
            try:
                int(pcode)
                pass
            except:
                pcode_types[pcode].add(pcode)
        else:
            pcode_types[pcode].add(pcode)

# %%
def is_postal_code(elem):
    return (elem.attrib['k'] == "addr:postcode")

# %%
def audit_pcodes(filename):
    filename = open(filename, "r")
    pcode_types = defaultdict(set)
    for event, elem in ET.iterparse(filename, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_postal_code(tag):
                    audit_pcode_type(pcode_types, tag.attrib['v'])
    
    return pcode_types

# %%
def update_pcodes(pcode, pcode_types):
        
    # Loop through dictionary and correct formats to get just integer postcode
    for pcode_type, value_set in pcode_types.iteritems():
        if pcode in value_set:
            '''Order of corrections matters, as i.e. D01F5P2 -> D01 -> 1'''
            if pcode_type == "Dublin":
                pcode = re.sub("Dublin ", "", pcode)
            if pcode_type == "Two items":
                pcode = pcode.split(" ")
                pcode = pcode[0]
            if pcode_type == "too long":
                pcode = pcode[0:3]
            if pcode_type == "D":
                pcode = re.sub("0", "", pcode[1:])

    return pcode

# %% [markdown]
# #### 4.2.2 Postal Code Audit

# %%
pcode_types = audit_pcodes(filename)
pprint.pprint(dict(pcode_types))
# Out:
# {'D': set(['D01',
#            'D02',
#            'D03',
#            'D04',
#            'D05',
#            'D06',
#            'D07',
#            'D08',
#            'D11',
#            'D12',
#            'D13',
#            'D14',
#            'D15',
#            'D18',
#            'D6W']),
#  'Dublin': set(['Dublin 14', 'Dublin 15', 'Dublin 2', 'Dublin 24']),
#  'Two items': set(['A94 FA39',
#                    'A94 PC95',
#                    'A96 DF24',
#                    'A96 XN50',
#                    'A98 KC91',
#                    'D01 V6V6',
#                    'D01 WY49',
#                    'D02 NH04',
#                    'D07 X9YN',
#                    'D08 P3K4',
#                    'D15 A259',
#                    'D15 A3A8',
#                    'D15 A4ET',
#                    'D15 A583',
#                    'D15 A9WH',
#                    'D15 ACP4',
#                    'D15 AE72',
#                    'D15 AF80',
#                    'D15 AK27',
#                    'D15 AP60',
#                    'D15 AW77',
#                    'D15 AW9X',
#                    'D15 C9K2',
#                    'D15 C9Y5',
#                    'D15 CD30',
#                    'D15 CDC4',
#                    'D15 CK81',
#                    'D15 CP38',
#                    'D15 CP7W',
#                    'D15 CPR6',
#                    'D15 CR26',
#                    'D15 CR68',
#                    'D15 CR90',
#                    'D15 CTW0',
#                    'D15 CX54',
#                    'D15 CX95',
#                    'D15 CYN0',
#                    'D15 DF86',
#                    'D15 DK71',
#                    'D15 DP74',
#                    'D15 DX0H',
#                    'D15 DX90',
#                    'D15 DY24',
#                    'D15 E003',
#                    'D15 E024',
#                    'D15 E0H4',
#                    'D15 E196',
#                    'D15 E36N',
#                    'D15 E3WD',
#                    'D15 E671',
#                    'D15 E73K',
#                    'D15 E8FX',
#                    'D15 E8Y7',
#                    'D15 E972',
#                    'D15 EC6A',
#                    'D15 EE35',
#                    'D15 EK0F',
#                    'D15 EN23',
#                    'D15 EP3X',
#                    'D15 ET61',
#                    'D15 EY46',
#                    'D15 F3803',
#                    'D15 F59E',
#                    'D15 F673',
#                    'D15 F6R0',
#                    'D15 F782',
#                    'D15 F792',
#                    'D15 FD2E',
#                    'D15 FD37',
#                    'D15 FK60',
#                    'D15 FP79',
#                    'D15 FX09',
#                    'D15 HD96',
#                    'D15 HF72',
#                    'D15 HF8N',
#                    'D15 HR02',
#                    'D15 HY61',
#                    'D15 HY88',
#                    'D15 HY97',
#                    'D15 K004',
#                    'D15 K0WR',
#                    'D15 K224',
#                    'D15 K2FT',
#                    'D15 K304',
#                    'D15 K663',
#                    'D15 K6YR',
#                    'D15 K822',
#                    'D15 K8ER',
#                    'D15 K8YW',
#                    'D15 KD99',
#                    'D15 KR62',
#                    'D15 KX95',
#                    'D15 N5H6',
#                    'D15 N8CF',
#                    'D15 N8EK',
#                    'D15 NP7A',
#                    'D15 NX3P',
#                    'D15 NX83',
#                    'D15 NY59',
#                    'D15 P3XR',
#                    'D15 P5FN',
#                    'D15 PC66',
#                    'D15 PH90',
#                    'D15 PK53',
#                    'D15 PK71',
#                    'D15 PV2R',
#                    'D15 PW52',
#                    'D15 PX44',
#                    'D15 PY04',
#                    'D15 R242',
#                    'D15 R293',
#                    'D15 R8C9',
#                    'D15 R922',
#                    'D15 RD0Y',
#                    'D15 RH93',
#                    'D15 RK58',
#                    'D15 RR68',
#                    'D15 RX02',
#                    'D15 RX20',
#                    'D15 RY71',
#                    'D15 RY82',
#                    'D15 RYW7',
#                    'D15 T1FD',
#                    'D15 T8KE',
#                    'D15 TD5Y',
#                    'D15 TRX7',
#                    'D15 TVH4',
#                    'D15 V051',
#                    'D15 V2X4',
#                    'D15 V599',
#                    'D15 VF76',
#                    'D15 VK74',
#                    'D15 VP97',
#                    'D15 VW32',
#                    'D15 W2XF',
#                    'D15 W590',
#                    'D15 W9NX',
#                    'D15 WD5P',
#                    'D15 WE51',
#                    'D15 WF60',
#                    'D15 WF88',
#                    'D15 WN53',
#                    'D15 WP58',
#                    'D15 WTY7',
#                    'D15 WYC0',
#                    'D15 X066',
#                    'D15 X732',
#                    'D15 X7NK',
#                    'D15 XC6R',
#                    'D15 XCF9',
#                    'D15 XD29',
#                    'D15 XE63',
#                    'D15 XEE9',
#                    'D15 XH58',
#                    'D15 XP60',
#                    'D15 XR70',
#                    'D15 XR8K',
#                    'D15 XT29',
#                    'D15 XY05',
#                    'D15 Y235',
#                    'D15 Y291',
#                    'D15 Y326',
#                    'D15 Y519',
#                    'D15 Y681',
#                    'D15 Y7TX',
#                    'D15 Y99K',
#                    'D15 Y9WA',
#                    'D15 YA32',
#                    'D15 YC1W',
#                    'D15 YD26',
#                    'D15 YF53',
#                    'D15 YF57',
#                    'D15 YK8A',
#                    'D15 YN76',
#                    'D15 YP92',
#                    'D15 YXC2',
#                    'D15 YY8W',
#                    'D18 K0EN',
#                    'D18 KX90',
#                    'D18 N927',
#                    'D18 P997',
#                    'D18 T8N4',
#                    'D18 V260',
#                    'D18 VX05',
#                    'D18 VY24']),
#  'too long': set(['A96X259', 'D01F5P2', 'D01X2P2'])}

# %% [markdown]
# #### 4.1.3 Postal Code Update Function Test

# %%
for pcode_type, value_set in pcode_types.iteritems():
    for pcode in value_set:
        better_code = update_pcodes(pcode, pcode_types)
        print pcode, "=>", better_code
# Out:
# D01X2P2 => 1
# D01F5P2 => 1
# A96X259 => A96
# Dublin 2 => 2
# Dublin 14 => 14
# Dublin 24 => 24
# Dublin 15 => 15
# D07 => 7
# D06 => 6
# D12 => 12
# D04 => 4
# D15 => 15
# D02 => 2
# D01 => 1
# D13 => 13
# D18 => 18
# D05 => 5
# D14 => 14
# D08 => 8
# D03 => 3
# D6W => 6W
# D11 => 11
# D15 EC6A => D15
# D08 P3K4 => D08
# D15 XP60 => D15
# D15 YY8W => D15
# D15 F782 => D15
# D15 E671 => D15
# D15 K304 => D15
# D15 PX44 => D15
# D15 TRX7 => D15
# D15 W590 => D15
# D15 F673 => D15
# D15 E8FX => D15
# A98 KC91 => A98
# D15 NY59 => D15
# D15 AW9X => D15
# D15 CR26 => D15
# D15 XE63 => D15
# D15 Y9WA => D15
# D15 WF88 => D15
# D15 YK8A => D15
# D02 CC60 => D02
# D18 KX90 => D18
# D15 VF76 => D15
# D15 FX09 => D15
# D15 HF8N => D15
# D15 YA32 => D15
# D15 CR90 => D15
# D01 V6V6 => D01
# D15 XC6R => D15
# D15 K004 => D15
# D15 XR70 => D15
# D18 T8N4 => D18
# D15 YP92 => D15
# D15 ACP4 => D15
# D15 PK71 => D15
# D15 DC2W => D15
# D15 KR62 => D15
# D15 ET61 => D15
# D15 K6YR => D15
# D15 F3803 => D15
# D15 P5FN => D15
# D15 R242 => D15
# D07 X9YN => D07
# D15 K8YW => D15
# D15 HD96 => D15
# D15 WTY7 => D15
# D15 PW52 => D15
# D15 YD26 => D15
# D15 P3XR => D15
# D15 A3A8 => D15
# D15 R8C9 => D15
# D15 R922 => D15
# A96 DF24 => A96
# D15 EP3X => D15
# D15 AF80 => D15
# D15 CD30 => D15
# D15 PY04 => D15
# D15 KX95 => D15
# D15 WF60 => D15
# D15 CP7W => D15
# A94 PC95 => A94
# D15 WP58 => D15
# D15 X066 => D15
# D02 NH04 => D02
# D15 A259 => D15
# D15 E196 => D15
# D15 XH58 => D15
# D15 YC1W => D15
# D15 K2FT => D15
# D15 PV2R => D15
# D15 EY46 => D15
# D15 HY61 => D15
# D18 V260 => D18
# D15 K0WR => D15
# D18 VX05 => D18
# D15 CYN0 => D15
# D15 F6R0 => D15
# D15 NP7A => D15
# D15 DK71 => D15
# D15 T1FD => D15
# D01 WY49 => D01
# D18 N927 => D18
# D15 XD29 => D15
# D15 VW32 => D15
# D15 PK53 => D15
# D15 CDC4 => D15
# D15 Y7TX => D15
# D15 DY24 => D15
# D15 HR02 => D15
# D15 XR8K => D15
# D15 C9K2 => D15
# D15 NX3P => D15
# D15 DF86 => D15
# D15 RY82 => D15
# A96 XN50 => A96
# D15 RYW7 => D15
# D15 WE51 => D15
# D15 E972 => D15
# D15 K224 => D15
# D15 E0H4 => D15
# D15 CPR6 => D15
# D15 DX0H => D15
# D15 FK60 => D15
# D15 EN23 => D15
# D15 AW77 => D15
# D15 XEE9 => D15
# D15 K8ER => D15
# D15 CR68 => D15
# D15 YN76 => D15
# D15 CX95 => D15
# D18 P997 => D18
# D15 WN53 => D15
# D15 N8CF => D15
# D15 WD5P => D15
# D15 RD0Y => D15
# D15 E73K => D15
# D18 K0EN => D18
# D15 A583 => D15
# D15 RR68 => D15
# D15 RH93 => D15
# D15 W2XF => D15
# D15 Y291 => D15
# D15 E36N => D15
# D15 E024 => D15
# D15 EK0F => D15
# D15 YXC2 => D15
# D15 A9WH => D15
# D15 HY97 => D15
# D15 RK58 => D15
# D15 Y99K => D15
# D15 W9NX => D15
# D18 VY24 => D18
# D15 VP97 => D15
# D15 DX90 => D15
# D15 EE35 => D15
# D15 FP79 => D15
# D15 KD99 => D15
# D15 Y326 => D15
# D15 E8Y7 => D15
# D15 R293 => D15
# D15 V051 => D15
# D15 WYC0 => D15
# D15 A4ET => D15
# D15 N8EK => D15
# D15 YF53 => D15
# A94 FA39 => A94
# D15 HY88 => D15
# D15 RY71 => D15
# D15 Y681 => D15
# D15 T8KE => D15
# D15 AK27 => D15
# D15 PC66 => D15
# D15 Y519 => D15
# D15 VK74 => D15
# D15 YF57 => D15
# D15 CTW0 => D15
# D15 AP60 => D15
# D15 CX54 => D15
# D15 N5H6 => D15
# D15 X732 => D15
# D15 Y235 => D15
# D15 C9Y5 => D15
# D15 F59E => D15
# D15 FD37 => D15
# D15 NX83 => D15
# D15 TVH4 => D15
# D15 F792 => D15
# D15 AE72 => D15
# D15 TD5Y => D15
# D15 XT29 => D15
# D15 E003 => D15
# D15 HF72 => D15
# D15 K663 => D15
# D15 K822 => D15
# D15 CP38 => D15
# D15 DP74 => D15
# D15 PH90 => D15
# D15 XCF9 => D15
# D15 FD2E => D15
# D15 V599 => D15
# D15 CK81 => D15
# D15 RX02 => D15
# D15 XY05 => D15
# D15 E3WD => D15
# D15 V2X4 => D15
# D15 X7NK => D15

# %% [markdown]
# ## 5 Correct data, store as JSON and import into MongoDB

# %% [markdown]
# #### 5.1 Import and predefine methods and variables

# %%
import codecs
import json
from pymongo import MongoClient

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]

# %% [markdown]
# #### 5.2 Define Helper functions

# %%
def shape_element(element):
    data = []
    node = {}
    node["pos"]=[]
    if element.tag == "node" or element.tag == "way" :
        node["type"] = element.tag
        for key in element.keys():
            if key in CREATED:
                if "created" not in node.keys():
                    node["created"] = {}
                node["created"][key] = element.attrib[key]
            elif key in ("lat", "lon"):
                try:
                    node['pos']=[float(element.attrib['lat']),float(element.attrib['lon'])]
                except KeyError:
                    pass
            else:
                node[key] = element.attrib[key]

        for tag in element.iter("tag"):
            if not(problemchars.search(tag.attrib['k'])):
                if tag.attrib['k'].startswith("addr:"):
                        addr_fields = tag.attrib['k'].split(':')
                        if len(addr_fields) == 2:
                            if 'address' not in node.keys():
                                node['address'] = {}
                            if addr_fields[1] == "street":
                                node["address"][addr_fields[1]] = update_streets(tag.attrib['v'], mapping, st_types)
                            elif addr_fields[1] == "postcode":
                                node["address"][addr_fields[1]] = update_pcodes(tag.attrib['v'], pcode_types)
                            else:
                                node["address"][addr_fields[1]] = tag.attrib['v']
                else:
                    node[tag.attrib['k']] = tag.attrib['v']
        
        for nd in element.iter("nd"):
            if "node_refs" not in node.keys(): 
                node["node_refs"] = []
            node["node_refs"].append(nd.attrib['ref'])
        
        return node
    else:
        return None

# %%
def process_map(file_in):
    data = []
    for _, element in ET.iterparse(file_in):
        el = shape_element(element)
        if el:
            data.append(el)
    return data

# %%
def write_json(file_in):
    process_map(file_in)
    file_out = "{0}.json".format(file_in)
    with codecs.open(file_out, "w") as fo:
        fo.write(json.dumps(data))

# %% [markdown]
# #### 5.3 Convert to JSON format and dump as file

# %%
data = process_map(filename)

# %%
pprint.pprint(data[0])
# Out:
# {'created': {'changeset': '5277755',
#              'timestamp': '2010-07-21T10:37:10Z',
#              'uid': '114310',
#              'user': 'Joe E',
#              'version': '3'},
#  'id': '384519',
#  'pos': [53.3763419, -6.3699187],
#  'type': 'node'}

# %%
file_out = "{0}.json".format(file_in)
with codecs.open(file_out, "w") as fo:
    fo.write(json.dumps(data))

# %% [markdown]
# #### 5.4 Insert into MongoDB

# %%
def insert_data(jsonfile):
    
    print jsonfile

    client = MongoClient("mongodb://localhost:27017")
    db = client.examples

    with open(jsonfile) as f:
        data = json.loads(f.read())
        db.dublin.insert_many(data)

# %%
#jsonfile = "/home/pi/Downloads/dublin_ireland.json"
jsonfile = "{0}.json".format(filename)
insert_data(jsonfile)
# Out:
# /home/pi/Downloads/dublin_ireland.json

# %% [markdown]
# # 6 Query Data in MongoDB

# %% [markdown]
# #### 6.1 Setup Mongo Client and load Database

# %%
client = MongoClient("mongodb://localhost:27017")
db = client.examples

# %% [markdown]
# #### 6.2 Define aggregate function to save some typing

# %%
def aggregate(pipeline):
    return [doc for doc in db.dublin.aggregate(pipeline)]

# %% [markdown]
# #### 6.3 Nodes & Ways in Dataset

# %%
nodes = db.dublin.find({"type": "node"}).count()
ways = db.dublin.find({"type": "way"}).count()

print "There are " + str(nodes) + " nodes and " + str(ways) + " ways in the dataset"
# Out:
# There are 1068553 nodes and 187688 ways in the dataset

# %% [markdown]
# #### 6.4 User stats

# %%
list = db.dublin.distinct("created.user")
print len(list)
# Out:
# 1108

# %%
superusers = [{"$group": {"_id": "$created.user",
                          "count": {"$sum": 1}}},
              {"$sort": {"count": -1}},
              {"$limit": 10}
                                ]
pprint.pprint(aggregate(superusers))
# Out:
# [{u'_id': u'Nick Burrett', u'count': 236755},
#  {u'_id': u'mackerski', u'count': 183610},
#  {u'_id': u'brianh', u'count': 154844},
#  {u'_id': u'Dafo43', u'count': 150829},
#  {u'_id': u'Conormap', u'count': 63958},
#  {u'_id': u'Ignobilis', u'count': 52850},
#  {u'_id': u'VictorIE', u'count': 48596},
#  {u'_id': u'Autarch', u'count': 21800},
#  {u'_id': u'wigs', u'count': 20792},
#  {u'_id': u'Blazejos', u'count': 19569}]

# %% [markdown]
# ##### 6.5 Most common amenities

# %%
amenities = [{"$match": {"amenity": {"$ne": None}}},
             {"$group": {"_id": "$amenity",
                          "count": {"$sum": 1}}},
             {"$sort": {"count": -1}},
             {"$limit": 10}
                                ]
pprint.pprint(aggregate(amenities))
# Out:
# [{u'_id': u'parking', u'count': 2134},
#  {u'_id': u'pub', u'count': 698},
#  {u'_id': u'restaurant', u'count': 650},
#  {u'_id': u'fast_food', u'count': 586},
#  {u'_id': u'cafe', u'count': 561},
#  {u'_id': u'school', u'count': 540},
#  {u'_id': u'post_box', u'count': 437},
#  {u'_id': u'place_of_worship', u'count': 389},
#  {u'_id': u'bench', u'count': 346},
#  {u'_id': u'bicycle_parking', u'count': 302}]

# %% [markdown]
# ##### 6.6 Religions for places of worship

# %%
religion = [{"$match": {"amenity": "place_of_worship",
                        "religion": {"$ne": None}}},
              {"$group": {"_id": "$religion",
                          "count": {"$sum": 1}}},
              {"$sort": {"count": -1}},
              {"$limit": 10}
                                ]
pprint.pprint(aggregate(religion))
# Out:
# [{u'_id': u'christian', u'count': 348},
#  {u'_id': u'buddhist', u'count': 4},
#  {u'_id': u'muslim', u'count': 2},
#  {u'_id': u'jewish', u'count': 2},
#  {u'_id': u'sikh', u'count': 1},
#  {u'_id': u'bahai', u'count': 1},
#  {u'_id': u'multifaith', u'count': 1},
#  {u'_id': u'hindu', u'count': 1}]

# %% [markdown]
# ##### 6.6 Street with most pubs

# %%
pub_street = [{"$match": {"amenity": "pub"}},
              {"$group": {"_id": "$address.street",
                          "count": {"$sum": 1}}},
              {"$sort": {"count": -1}},
              {"$limit": 10}
                                ]
pprint.pprint(aggregate(pub_street))
# Out:
# [{u'_id': None, u'count': 334},
#  {u'_id': u'Main Street', u'count': 10},
#  {u'_id': u'Thomas Street', u'count': 6},
#  {u'_id': u'Duke Street', u'count': 5},
#  {u'_id': u'Wexford Street', u'count': 5},
#  {u'_id': u'Camden Street Lower', u'count': 5},
#  {u'_id': u'Baggot Street Lower', u'count': 5},
#  {u'_id': u"Harold's Cross Road", u'count': 5},
#  {u'_id': u'Phibsborough Road', u'count': 5},
#  {u'_id': u'Dame Street', u'count': 4}]

# %% [markdown]
# ##### 6.7 Leisure resources

# %%
leisure = [{"$match": {"leisure": {"$ne": None}}},
              {"$group": {"_id": "$leisure",
                        "count": {"$sum": 1}}},
              {"$sort": {"count": -1}},
              {"$limit": 10}
                                ]
pprint.pprint(aggregate(leisure))
# Out:
# [{u'_id': u'pitch', u'count': 1304},
#  {u'_id': u'park', u'count': 881},
#  {u'_id': u'sports_centre', u'count': 241},
#  {u'_id': u'garden', u'count': 205},
#  {u'_id': u'playground', u'count': 162},
#  {u'_id': u'golf_course', u'count': 98},
#  {u'_id': u'picnic_table', u'count': 50},
#  {u'_id': u'common', u'count': 32},
#  {u'_id': u'recreation_ground', u'count': 30},
#  {u'_id': u'swimming_pool', u'count': 23}]

# %% [markdown]
# ##### 6.8 Listed cities

# %%
city = [{"$match": {"address.city": {"$ne": None}}},
              {"$group": {"_id": "$address.city",
                        "count": {"$sum": 1}}},
              {"$sort": {"count": -1}},
              {"$limit": 10}
                                ]
pprint.pprint(aggregate(city))
# Out:
# [{u'_id': u'Dublin', u'count': 7331},
#  {u'_id': u'Lucan', u'count': 1322},
#  {u'_id': u'Dublin 6', u'count': 990},
#  {u'_id': u'Blanchardstown', u'count': 943},
#  {u'_id': u'Dublin 1', u'count': 390},
#  {u'_id': u'Dublin 8', u'count': 324},
#  {u'_id': u'Dublin 7', u'count': 315},
#  {u'_id': u'Dublin 2', u'count': 297},
#  {u'_id': u'Dublin 3', u'count': 240},
#  {u'_id': u'Dublin 6W', u'count': 196}]

# %%
amenities_wo_address = [{"$match": {"address.street": None,
                                    "amenity": {"$ne": None},
                                    "pos": {"$ne": None}}},
                        {"$group": {"_id": "Amenities w/o address but positional data",
                                    "count": {"$sum": 1}}}
                        ]
pprint.pprint(aggregate(amenities_wo_address))
# Out:
# [{u'_id': u'Amenities w/o address but positional data', u'count': 7342}]
